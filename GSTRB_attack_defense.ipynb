# %%
import pandas as pd
import numpy as np

import os
import pathlib

import cv2 #영상처리에 사용하는 오픈소스 라이브러리, 컴퓨터가 사람 눈처럼 인식할 수 있게 처리
from PIL import Image # 파이썬 이미지 처리 pillow 라이브러리
from tensorflow.keras.preprocessing import image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator #imagedatagenerater는 이미지를 학습시킬 때 학습 데이터의 양이 적을 경우 학습데이터를 조금씩 변형 시켜서 학습데이터의 양을 늘리는 방식중 하나
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img, load_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')#그래프 스타일 지정

from tqdm.auto import tqdm

#난수 랜덤성 고정
np.random.seed(42)

# %matplotlib inline

# %%
cd /content/drive/MyDrive/magnet/GTSRB
# Out:
# /content/drive/.shortcut-targets-by-id/1g8sAN62Ni-dYl7F2MXeUJoyjmxEjibt8/GTSRB

# %% [markdown]
# ### setup_data

# %%
import numpy as np
import os
import gzip
import urllib.request

from keras.models import load_model

class GTSRB:
    def __init__(self):
        imgs_path = "Train"
        data_list = []
        labels_list = []
        # result_class = [3]

        result_class = [3,7, 9, 10, 11, 12, 13, 17, 18, 25, 35, 38]

        for i in result_class:
            i_path = os.path.join(imgs_path, str(i)) # 3, 7, 9, 10, 11, 12,13, 17, 18, 25, 35, 38
            num = 0
            for img in os.listdir(i_path):
          
                im = Image.open(i_path +'/'+ img)
                im = im.resize((32,32))
                im = np.array(im)
                im = im.reshape((3,32,32)).transpose((1,2,0))
                # im = im.resize((3,32,32))
                # im = np.array(im)

                data_list.append(im/255)
                labels_list.append(i)
                num = num + 1
                if num == 1000:
                    break;


        data = np.array(data_list)
        labels = np.array(labels_list)

        # data = (data.astype(np.float32) - 127.5) / 127.5
        labels = to_categorical(labels)

        VALIDATION_SIZE = 5000
        
        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(np.array(data), labels, test_size=0.4)    

    @staticmethod
    def print():
        return "GTSRB"


class GTSRBModel:
    def __init__(self, restore, session=None):
        self.num_channels = 3
        self.image_size = 32
        self.num_labels = 12
        
        model = Sequential()

        model.add(Conv2D(64, (3, 3),input_shape=(32, 32, 3)))
        model.add(Activation('relu'))
        model.add(Conv2D(64, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        
        model.add(Conv2D(128, (3, 3)))
        model.add(Activation('relu'))
        model.add(Conv2D(128, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        
        model.add(Flatten())
        model.add(Dense(256))
        model.add(Activation('relu'))
        model.add(Dense(256))
        model.add(Activation('relu'))
        model.add(Dense(39))

        model.load_weights(restore)

        self.model = model

    def predict(self, data):
        return self.model(data)

# %%
data = GTSRB()

# %% [markdown]
# ### train_models

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
import os


def train(data, file_name, num_epochs=50, batch_size=128):
    """
    Standard neural network training procedure.
    """
    model = Sequential()

    IMG_HEIGHT = 32
    IMG_WIDTH = 32

    # 첫번째 Convolutional Layer : 입력 데이터로부터 특징을 추출
    model.add(Conv2D(filters=96, kernel_size=3, activation='relu', input_shape=data.x_train.shape[1:]))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(rate=0.25))

    # 두번째 Convolutional Layer
    model.add(Conv2D(filters=192, kernel_size=3, activation='relu'))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Dropout(rate=0.25)) # 인풋데이터의 25%를 무작위로 0으로 만듦

    # 세번째 Convolutional Layer
    model.add(Conv2D(filters=192, kernel_size=3, activation='relu')) # 특징을 추출하는 기능을 하는 필터, 비선형 값으로 바꿔주는 activation 함수->relu
    # model.add(GlobalAveragePooling2D())
    model.add(Flatten())

    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(39, activation='softmax'))


    # 모델 컴파일 하기
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()

    # 모델 핏하기
    EPOCHS = 50
    model.fit(data.x_train, data.y_train,
              validation_data = (data.x_test, data.y_test), 
              epochs=EPOCHS, steps_per_epoch=60
              )

    if file_name != None:
        model.save(file_name)

    return model


if not os.path.isdir('models'):
    os.makedirs('models')

model = train(data, "models/example_classifier2", num_epochs=30)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 96)        2688
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 96)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 96)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 192)       166080
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 192)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 192)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 192)         331968
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 64)                196672
#
#  dense_1 (Dense)             (None, 39)                2535
#
# =================================================================
# Total params: 699,943
# Trainable params: 699,943
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 60/60 [==============================] - 13s 21ms/step - loss: 0.1490 - accuracy: 0.1258 - val_loss: 0.0886 - val_accuracy: 0.1841
# Epoch 2/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.2013 - val_loss: 0.0807 - val_accuracy: 0.2775
# Epoch 3/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.2013 - val_loss: 0.0831 - val_accuracy: 0.2390
# Epoch 4/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0819 - accuracy: 0.2181 - val_loss: 0.0798 - val_accuracy: 0.2885
# Epoch 5/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.3406 - val_loss: 0.0727 - val_accuracy: 0.3984
# Epoch 6/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0626 - accuracy: 0.4698 - val_loss: 0.0647 - val_accuracy: 0.4670
# Epoch 7/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0600 - accuracy: 0.5017 - val_loss: 0.0586 - val_accuracy: 0.5275
# Epoch 8/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.6007 - val_loss: 0.0560 - val_accuracy: 0.5659
# Epoch 9/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0462 - accuracy: 0.6493 - val_loss: 0.0555 - val_accuracy: 0.5907
# Epoch 10/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.6862 - val_loss: 0.0509 - val_accuracy: 0.5962
# Epoch 11/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0340 - accuracy: 0.7821 - val_loss: 0.0436 - val_accuracy: 0.6896
# Epoch 12/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.7819 - val_loss: 0.0437 - val_accuracy: 0.6868
# Epoch 13/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0260 - accuracy: 0.8289 - val_loss: 0.0397 - val_accuracy: 0.7060
# Epoch 14/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 0.8574 - val_loss: 0.0394 - val_accuracy: 0.7225
# Epoch 15/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.8758 - val_loss: 0.0354 - val_accuracy: 0.7610
# Epoch 16/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9044 - val_loss: 0.0356 - val_accuracy: 0.7692
# Epoch 17/50
# 60/60 [==============================] - 1s 8ms/step - loss: 0.0152 - accuracy: 0.9094 - val_loss: 0.0341 - val_accuracy: 0.7665
# Epoch 18/50
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0117 - accuracy: 0.9430 - val_loss: 0.0354 - val_accuracy: 0.7747
# Epoch 19/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9513 - val_loss: 0.0368 - val_accuracy: 0.7912
# Epoch 20/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9597 - val_loss: 0.0349 - val_accuracy: 0.8049
# Epoch 21/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9664 - val_loss: 0.0378 - val_accuracy: 0.7885
# Epoch 22/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9747 - val_loss: 0.0349 - val_accuracy: 0.8159
# Epoch 23/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9715 - val_loss: 0.0405 - val_accuracy: 0.7802
# Epoch 24/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9664 - val_loss: 0.0357 - val_accuracy: 0.7995
# Epoch 25/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9832 - val_loss: 0.0458 - val_accuracy: 0.7967
# Epoch 26/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9883 - val_loss: 0.0443 - val_accuracy: 0.7775
# Epoch 27/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9782 - val_loss: 0.0372 - val_accuracy: 0.8324
# Epoch 28/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9883 - val_loss: 0.0379 - val_accuracy: 0.8324
# Epoch 29/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9966 - val_loss: 0.0429 - val_accuracy: 0.8324
# Epoch 30/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9950 - val_loss: 0.0403 - val_accuracy: 0.8242
# Epoch 31/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9933 - val_loss: 0.0438 - val_accuracy: 0.8104
# Epoch 32/50
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0042 - accuracy: 0.9849 - val_loss: 0.0390 - val_accuracy: 0.8407
# Epoch 33/50
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.8324
# Epoch 34/50
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0022 - accuracy: 0.9966 - val_loss: 0.0417 - val_accuracy: 0.8269
# Epoch 35/50
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0033 - accuracy: 0.9950 - val_loss: 0.0521 - val_accuracy: 0.8104
# Epoch 36/50
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0037 - accuracy: 0.9899 - val_loss: 0.0411 - val_accuracy: 0.8379
# Epoch 37/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.9983 - val_loss: 0.0435 - val_accuracy: 0.8324
# Epoch 38/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.8159
# Epoch 39/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9966 - val_loss: 0.0481 - val_accuracy: 0.8407
# Epoch 40/50
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0016 - accuracy: 0.9950 - val_loss: 0.0462 - val_accuracy: 0.8379
# Epoch 41/50
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0039 - accuracy: 0.9950 - val_loss: 0.0479 - val_accuracy: 0.8242
# Epoch 42/50
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9799 - val_loss: 0.0491 - val_accuracy: 0.8022
# Epoch 43/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9883 - val_loss: 0.0423 - val_accuracy: 0.8324
# Epoch 44/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9932 - val_loss: 0.0465 - val_accuracy: 0.8269
# Epoch 45/50
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9866 - val_loss: 0.0399 - val_accuracy: 0.8187
# Epoch 46/50
# 39/60 [==================>...........] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 3000 batches). You may need to use the repeat() function when building your dataset.
# 60/60 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.8324

# %%
loss, accuracy = classifier.model.evaluate(data.x_test, data.y_test)

print('test set accuracy: ', accuracy * 100)
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0463 - accuracy: 0.8324
# test set accuracy:  83.24176073074341

# %% [markdown]
# ### defensvie_model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import os
import numpy as np
from keras.layers.core import Lambda
from keras.layers.merge import Average, add
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, AveragePooling2D
from keras.models import Model
import keras.regularizers as regs


class DenoisingAutoEncoder:
    def __init__(self, image_shape,
                 structure,
                 v_noise=0.0,
                 activation="relu",
                 model_dir="./defensive_models/",
                 reg_strength=0.0):
        """
        Denoising autoencoder.

        image_shape: Shape of input image. e.g. 28, 28, 1.
        structure: Structure of autoencoder.
        v_noise: Volume of noise while training.
        activation: What activation function to use.
        model_dir: Where to save / load model from.
        reg_strength: Strength of L2 regularization.
        """
        h, w, c = image_shape
        self.image_shape = image_shape # shape of input image (32,32,3)
        self.model_dir = model_dir 
        self.v_noise = v_noise

        input_img = Input(shape=self.image_shape)
        x = input_img

        
        for layer in structure: 
            if isinstance(layer, int):
                x = Conv2D(layer, (3, 3), activation=activation, padding="same",
                           activity_regularizer=regs.l2(reg_strength))(x)
            elif layer == "max":
                x = MaxPooling2D((2, 2), padding="same")(x)
            elif layer == "average":
                x = AveragePooling2D((2, 2), padding="same")(x)
            else:
                print(layer, "is not recognized!")
                exit(0)

        for layer in reversed(structure):
            if isinstance(layer, int):
                x = Conv2D(layer, (3, 3), activation=activation, padding="same",
                           activity_regularizer=regs.l2(reg_strength))(x)
            elif layer == "max" or layer == "average":
                x = UpSampling2D((2, 2))(x)

        decoded = Conv2D(c, (3, 3), activation='sigmoid', padding='same',
                         activity_regularizer=regs.l2(reg_strength))(x)
        self.model = Model(input_img, decoded)

    def train(self, data, archive_name, num_epochs=100, batch_size=32):
        self.model.compile(loss='mean_squared_error',
                           metrics=['mean_squared_error'],
                           optimizer='adam')
        print(data.x_train.shape)
        noise = self.v_noise * np.random.normal(size=np.shape(data.x_train))
        noisy_train_data = data.x_train + noise
        noisy_train_data = np.clip(noisy_train_data, 0.0, 1.0)

        self.model.fit(noisy_train_data, data.x_train,
                       batch_size=batch_size,
                       validation_data=(data.x_test, data.x_test),
                       epochs=num_epochs,
                       shuffle=True)

        print(os.path.join(self.model_dir, archive_name))
        self.model.save(os.path.join(self.model_dir, archive_name))

    def load(self, archive_name, model_dir=None):
        if model_dir is None: model_dir = self.model_dir
        self.model.load_weights(os.path.join(model_dir, archive_name))


class PackedAutoEncoder:
    def __init__(self, image_shape, structure, data,
                 v_noise=0.1, n_pack=2, pre_epochs=3, activation="relu",
                 model_dir="./defensive_models/"):
        """
        Train different autoencoders.
        Demo code for graybox scenario.

        pre_epochs: How many epochs do we train before fine-tuning.
        n_pack: Number of autoencoders we want to train at once.
        """
        self.v_noise = v_noise
        self.n_pack = n_pack
        self.model_dir = model_dir
        pack = []



        for i in range(n_pack):
            dae = DenoisingAutoEncoder(image_shape, structure, v_noise=v_noise,
                                       activation=activation, model_dir=model_dir)
            dae.train(data, "", num_epochs=pre_epochs)
            pack.append(dae.model)


        shared_input = Input(shape=image_shape, name="shared_input")
        outputs = [dae(shared_input) for dae in pack]
        avg_output = Average()(outputs)
        delta_outputs = [add([avg_output, Lambda(lambda x: -x)(output)])
                         for output in outputs]

        self.model = Model(inputs=shared_input, outputs=outputs+delta_outputs)

    def train(self, data, archive_name, alpha, num_epochs=10, batch_size=32):
        noise = self.v_noise * np.random.normal(size=np.shape(data.x_train))
        noisy_train_data = data.x_train + noise
        noisy_train_data = np.clip(noisy_train_data, 0.0, 1.0)

        train_zeros = [np.zeros_like(data.x_train)] * self.n_pack
        val_zeros = [np.zeros_like(data.x_test)] * self.n_pack

        self.model.compile(loss="mean_squared_error", optimizer="adam",
                           loss_weights=[1.0]*self.n_pack + [-alpha]*self.n_pack)

        self.model.fit(noisy_train_data,
                       [data.x_train]*self.n_pack + train_zeros,
                       batch_size=batch_size,
                       validation_data=(data.x_test,
                            [data.x_test]*self.n_pack+val_zeros),
                       epochs=num_epochs,
                       shuffle=True)

        for i in range(self.n_pack):
            model = Model(self.model.input, self.model.outputs[i])
            self.model.save("")
            print(os.path.join(self.model_dir, archive_name+"_"+str(i)))
            self.model.save(os.path.join(self.model_dir, archive_name+"_"+str(i)))

    def load(self, archive_name, model_dir=None):
        if model_dir is None: model_dir = self.model_dir
        self.model.load_weights(os.path.join(model_dir, archive_name))

# %%
DAE = DenoisingAutoEncoder
PAE = PackedAutoEncoder

shape = [32, 32, 3]
combination_I = [3, "average", 3]
combination_II = [3]
activation = "sigmoid"
reg_strength = 1e-9
epochs = 500

# data = GTSRB()

# AE_II = PAE(shape, combination_II, data, v_noise=0.025, activation=activation, n_pack=8)
# AE_II.train(data, "0825_8_PAE_GTSRB_II", alpha=.2, num_epochs=epochs)

# AE_II = PAE(shape, combination_II, data, v_noise=0.025, activation=activation)
# AE_II.train(data, "0826_PAE_GTSRB_II", alpha=.2, num_epochs=epochs)    

# AE_II = PAE(shape, combination_II, data, v_noise=0.025, activation=activation, n_pack=32)
# AE_II.train(data, "O32_PAE_GTSRB_II", alpha=.2, num_epochs=epochs)  

AE_I = DAE(shape, combination_I, v_noise=0.1, activation=activation,
           reg_strength=reg_strength)
AE_I.train(data, "500_DAE_GTSRB_I", num_epochs=epochs)

AE_II = DAE(shape, combination_II, v_noise=0.1, activation=activation,
            reg_strength=reg_strength)
AE_II.train(data, "500_DAE_GTSRB_II", num_epochs=epochs)
# Out:
# (7023, 32, 32, 3)
# Epoch 1/500
# 220/220 [==============================] - 11s 10ms/step - loss: 0.0867 - mean_squared_error: 0.0866 - val_loss: 0.0756 - val_mean_squared_error: 0.0756
# Epoch 2/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0730 - mean_squared_error: 0.0730 - val_loss: 0.0662 - val_mean_squared_error: 0.0662
# Epoch 3/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0518 - mean_squared_error: 0.0518 - val_loss: 0.0467 - val_mean_squared_error: 0.0467
# Epoch 4/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0448 - mean_squared_error: 0.0448 - val_loss: 0.0443 - val_mean_squared_error: 0.0443
# Epoch 5/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Epoch 6/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
# Epoch 7/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
# Epoch 8/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0394 - val_mean_squared_error: 0.0394
# Epoch 9/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 10/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Epoch 11/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 12/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 13/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 14/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Epoch 15/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0373 - val_mean_squared_error: 0.0372
# Epoch 16/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 17/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0370 - mean_squared_error: 0.0370 - val_loss: 0.0369 - val_mean_squared_error: 0.0369
# Epoch 18/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 19/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0367 - val_mean_squared_error: 0.0367
# Epoch 20/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0367 - mean_squared_error: 0.0367 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 21/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 22/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 23/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0364 - val_mean_squared_error: 0.0364
# Epoch 24/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0365 - val_mean_squared_error: 0.0364
# Epoch 25/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 26/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 27/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 28/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 29/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 30/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 31/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 32/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 33/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0361 - val_mean_squared_error: 0.0361
# Epoch 34/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0361 - val_mean_squared_error: 0.0361
# Epoch 35/500
# 220/220 [==============================] - 2s 10ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0361 - val_mean_squared_error: 0.0361
# Epoch 36/500
# 220/220 [==============================] - 2s 10ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 37/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 38/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 39/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 40/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 41/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 42/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 43/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 44/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 45/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 46/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0359 - val_mean_squared_error: 0.0359
# Epoch 47/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 48/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 49/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 50/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 51/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 52/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 53/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0358 - val_mean_squared_error: 0.0357
# Epoch 54/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 55/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 56/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 57/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 58/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 59/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 60/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 61/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 62/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Epoch 63/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0346 - val_mean_squared_error: 0.0346
# Epoch 64/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 65/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# Epoch 66/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 67/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 68/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 69/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 70/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 71/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 72/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 73/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 74/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 75/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 76/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 77/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 78/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 79/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 80/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 81/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 82/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 83/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 84/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 85/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 86/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 87/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 88/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 89/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 90/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 91/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 92/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 93/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 94/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0203 - val_mean_squared_error: 0.0202
# Epoch 95/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 96/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0207 - mean_squared_error: 0.0206 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 97/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 98/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 99/500
# 220/220 [==============================] - 2s 10ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 100/500
# 220/220 [==============================] - 3s 12ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 101/500
# 220/220 [==============================] - 3s 15ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 102/500
# 220/220 [==============================] - 2s 11ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 103/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 104/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 105/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 106/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 107/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 108/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 109/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 110/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0196 - val_mean_squared_error: 0.0195
# Epoch 111/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 112/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 113/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 114/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0194 - val_mean_squared_error: 0.0193
# Epoch 115/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 116/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0192 - val_mean_squared_error: 0.0191
# Epoch 117/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 118/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 119/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0196 - mean_squared_error: 0.0195 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 120/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 121/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 122/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0194 - mean_squared_error: 0.0193 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 123/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 124/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 125/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 126/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 127/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 128/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 129/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 130/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 131/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 132/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 133/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 134/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 135/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 136/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 137/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 138/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 139/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 140/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 141/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 142/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 143/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 144/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 145/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 146/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 147/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 148/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 149/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 150/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0177 - mean_squared_error: 0.0176 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 151/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 152/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 153/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 154/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 155/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 156/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 157/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 158/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 159/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 160/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 161/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 162/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 163/500
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 164/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 165/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 166/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 167/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 168/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 169/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 170/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 171/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 172/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 173/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 174/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 175/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 176/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 177/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 178/500
# 220/220 [==============================] - 2s 10ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 179/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 180/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 181/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 182/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 183/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 184/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 185/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 186/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 187/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 188/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 189/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 190/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 191/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 192/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 193/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 194/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 195/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 196/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 197/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 198/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 199/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 200/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0165
# Epoch 201/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 202/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 203/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 204/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0172 - mean_squared_error: 0.0171 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 205/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 206/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 207/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 208/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 209/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 210/500
# 220/220 [==============================] - 2s 9ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 211/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 212/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 213/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 214/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 215/500
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 216/500
#  88/220 [===========>..................] - ETA: 0s - loss: 0.0172 - mean_squared_error: 0.0172

# %%
loss, accuracy = classfier.model.evaluate(data.x_test, data.y_test)

print('test set accuracy: ', accuracy * 100)

# %%
## utils.py -- utility functions
##
## Copyright (C) 2017, Dongyu Meng <zbshfmmm@gmail.com>.
##
## This program is licenced under the BSD 2-Clause licence,
## contained in the LICENCE file in this directory.

import pickle
import os
import numpy as np


def prepare_data(dataset, idx):
    """
    Extract data from index.

    dataset: Full, working dataset. Such as MNIST().
    idx: Index of test examples that we care about.
    return: X, targets, Y
    """
    return dataset.x_test[idx], dataset.y_test[idx], np.argmax(dataset.y_test[idx], axis=1)


def save_obj(obj, name, directory='./attack_data/'):
    with open(os.path.join(directory, name + '.pkl'), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)


def load_obj(name, directory='./attack_data/'):
    if name.endswith(".pkl"): name = name[:-4]
    with open(os.path.join(directory, name + '.pkl'), 'rb') as f:
        return pickle.load(f)

# %%
## setup_mnist.py -- mnist data and model loading code
##
## Copyright (C) 2016, Nicholas Carlini <nicholas@carlini.com>.
##
## This program is licenced under the BSD 2-Clause licence,
## contained in the LICENCE file in this directory.

## Modified for MagNet's use.

## worker.py -- evaluation code
##
## Copyright (C) 2017, Dongyu Meng <zbshfmmm@gmail.com>.
##
## This program is licenced under the BSD 2-Clause licence,
## contained in the LICENCE file in this directory.

import matplotlib
matplotlib.use('Agg')
from scipy.stats import entropy
from numpy.linalg import norm
from matplotlib.ticker import FuncFormatter
from keras.models import Sequential, load_model
from keras.activations import softmax
from keras.layers import Lambda
import numpy as np
import pylab
import os
import matplotlib.pyplot as plt


class AEDetector:
    def __init__(self, path, p=1):
        """
        Error based detector.
        Marks examples for filtering decisions.

        path: Path to the autoencoder used.
        p: Distance measure to use.
        """
        self.model = load_model(path)
        self.path = path
        self.p = p

    def mark(self, X):
        diff = np.abs(X - self.model.predict(X))
        marks = np.mean(np.power(diff, self.p), axis=(1,2,3))
        return marks

    def print(self):
        return "AEDetector:" + self.path.split("/")[-1]


class IdReformer:
    def __init__(self, path="IdentityFunction"):
        """
        Identity reformer.
        Reforms an example to itself.
        """
        self.path = path
        self.heal = lambda X: X

    def print(self):
        return "IdReformer:" + self.path


class SimpleReformer:
    def __init__(self, path):
        """
        Reformer.
        Reforms examples with autoencoder. Action of reforming is called heal.

        path: Path to the autoencoder used.
        """
        self.model = load_model(path)
        self.path = path

    def heal(self, X):
        X = self.model.predict(X)
        return np.clip(X, 0.0, 1.0)

    def print(self):
        return "SimpleReformer:" + self.path.split("/")[-1]


def JSD(P, Q):
    _P = P / norm(P, ord=1)
    _Q = Q / norm(Q, ord=1)
    _M = 0.5 * (_P + _Q)
    return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))


class DBDetector:
    def __init__(self, reconstructor, prober, classifier, option="jsd", T=1):
        """
        Divergence-Based Detector.

        reconstructor: One autoencoder.
        prober: Another autoencoder.
        classifier: Classifier object.
        option: Measure of distance, jsd as default.
        T: Temperature to soften the classification decision.
        """
        self.prober = prober
        self.reconstructor = reconstructor
        self.classifier = classifier
        self.option = option
        self.T = T

    def mark(self, X):
        return self.mark_jsd(X)

    def mark_jsd(self, X):
        Xp = self.prober.heal(X)
        Xr = self.reconstructor.heal(X)
        Pp = self.classifier.classify(Xp, option="prob", T=self.T)
        Pr = self.classifier.classify(Xr, option="prob", T=self.T)

        marks = [(JSD(Pp[i], Pr[i])) for i in range(len(Pr))]
        return np.array(marks)

    def print(self):
        return "Divergence-Based Detector"


class Classifier:
    def __init__(self, classifier_path):
        """
        Keras classifier wrapper.
        Note that the wrapped classifier should spit logits as output.

        classifier_path: Path to Keras classifier file.
        """
        self.path = classifier_path
        self.model = load_model(classifier_path)
        self.softmax = Sequential()
        self.softmax.add(Lambda(lambda X: softmax(X, axis=1), input_shape=(10,)))

    def classify(self, X, option="logit", T=1):
        if option == "logit":
            return self.model.predict(X)
        if option == "prob":
            logits = self.model.predict(X)/T
            return self.softmax.predict(logits)

    def print(self):
        return "Classifier:"+self.path.split("/")[-1]


class Operator:
    def __init__(self, data, classifier, det_dict, reformer):
        """
        Operator.
        Describes the classification problem and defense.

        data: Standard problem dataset. Including train, test, and validation.
        classifier: Target classifier.
        reformer: Reformer of defense.
        det_dict: Detector(s) of defense.
        """
        self.data = data
        self.classifier = classifier
        self.det_dict = det_dict
        self.reformer = reformer
        self.normal = self.operate(AttackData(data.x_train, np.argmax(data.y_train, axis=1), "Normal"))
        

    def get_thrs(self, drop_rate):
        """
        Get filtering threshold by marking validation set.
        """
        thrs = dict()
        for name, detector in self.det_dict.items():
            num = int(len(data.x_test) * drop_rate[name])
            marks = detector.mark(data.x_test)
            marks = np.sort(marks)
            thrs[name] = marks[-num]
        return thrs

    def operate(self, untrusted_obj):
        """
        For untrusted input(normal or adversarial), classify original input and
        reformed input. Classifier is unaware of the source of input.

        untrusted_obj: Input data.
        """
        X = untrusted_obj.data
        Y_true = untrusted_obj.labels

        X_prime = self.reformer.heal(X)
        Y = np.argmax(self.classifier.classify(X), axis=1)
        Y_judgement = (Y == Y_true[:len(X_prime)])
        Y_prime = np.argmax(self.classifier.classify(X_prime), axis=1)


        Y_prime_judgement = (Y_prime == Y_true[:len(X_prime)])

        return np.array(list(zip(Y_judgement, Y_prime_judgement)))

    def filter(self, X, thrs):
        """
        untrusted_obj: Untrusted input to test against.
        thrs: Thresholds.

        return:
        all_pass: Index of examples that passed all detectors.
        collector: Number of examples that escaped each detector.
        """
        collector = dict()
        all_pass = np.array(range(10000))
        for name, detector in self.det_dict.items():
            marks = detector.mark(X)
            idx_pass = np.argwhere(marks < thrs[name])
            collector[name] = len(idx_pass)
            all_pass = np.intersect1d(all_pass, idx_pass)
        return all_pass, collector

    def print(self):
        components = [self.reformer, self.classifier]
        return " ".join(map(lambda obj: getattr(obj, "print")(), components))


class AttackData:
    def __init__(self, examples, labels, name=""):
        """
        Input data wrapper. May be normal or adversarial.

        examples: Path or object of input examples.
        labels: Ground truth labels.
        """
        # if isinstance(examples, str): 
        #   self.data = load_obj(examples)
        # else: 
        self.data = examples
        self.labels = labels
        self.name = name

    def print(self):
        return "Attack:"+self.name


class Evaluator:
    def __init__(self, operator, untrusted_data, graph_dir="./graph"):
        """
        Evaluator.
        For strategy described by operator, conducts tests on untrusted input.
        Mainly stats and plotting code. Most methods omitted for clarity.

        operator: Operator object.
        untrusted_data: Input data to test against.
        graph_dir: Where to spit the graphs.
        """
        self.operator = operator
        self.untrusted_data = untrusted_data
        self.graph_dir = graph_dir
        self.data_package = operator.operate(untrusted_data)

    def bind_operator(self, operator):
        self.operator = operator
        self.data_package = operator.operate(self.untrusted_data)

    def load_data(self, data):
        self.untrusted_data = data
        self.data_package = self.operator.operate(self.untrusted_data)

    def get_normal_acc(self, normal_all_pass):
        """
        Break down of who does what in defense. Accuracy of defense on normal
        input.

        both: Both detectors and reformer take effect
        det_only: detector(s) take effect
        ref_only: Only reformer takes effect
        none: Attack effect with no defense
        """
        normal_tups = self.operator.normal
        num_normal = len(normal_tups)
        filtered_normal_tups = normal_tups[normal_all_pass]

        both_acc = sum(1 for _, XpC in filtered_normal_tups if XpC)/num_normal
        det_only_acc = sum(1 for XC, XpC in filtered_normal_tups if XC)/num_normal
        ref_only_acc = sum([1 for _, XpC in normal_tups if XpC])/num_normal
        none_acc = sum([1 for XC, _ in normal_tups if XC])/num_normal

        return both_acc, det_only_acc, ref_only_acc, none_acc

    def get_attack_acc(self, attack_pass):
        attack_tups = self.data_package
        num_untrusted = len(attack_tups)
        filtered_attack_tups = attack_tups[attack_pass]

        both_acc = 1 - sum(1 for _, XpC in filtered_attack_tups if not XpC)/num_untrusted
        det_only_acc = 1 - sum(1 for XC, XpC in filtered_attack_tups if not XC)/num_untrusted
        ref_only_acc = sum([1 for _, XpC in attack_tups if XpC])/num_untrusted
        none_acc = sum([1 for XC, _ in attack_tups if XC])/num_untrusted
        return both_acc, det_only_acc, ref_only_acc, none_acc

    def plot_various_confidences(self, graph_name, drop_rate,
                                 idx_file="example_idx",
                                 confs=(0.0, 10.0, 20.0, 30.0, 40.0),
                                 get_attack_data_name=lambda c: "example_carlini_"+str(c)):
        """
        Test defense performance against Carlini L2 attack of various confidences.

        graph_name: Name of graph file.
        drop_rate: How many normal examples should each detector drops?
        idx_file: Index of adversarial examples in standard test set.
        confs: A series of confidence to test against.
        get_attack_data_name: Function mapping confidence to corresponding file.
        """
        pylab.rcParams['figure.figsize'] = 6, 4
        fig = plt.figure(1, (6, 4))
        ax = fig.add_subplot(1, 1, 1)

        idx = original_labels_list
        X, _, Y = prepare_data(self.operator.data, idx)


        det_only = []
        ref_only = []
        both = []
        none = []

        print("\n==========================================================")
        print("Drop Rate:", drop_rate)
        thrs = self.operator.get_thrs(drop_rate)

        all_pass, _ = self.operator.filter(self.operator.data.x_train, thrs)
        all_on_acc, _, _, _ = self.get_normal_acc(all_pass)

        print("Classification accuracy with all defense on:", all_on_acc)

        for confidence in confs:
            f = get_attack_data_name(confidence)
            # self.load_data(AttackData(f, Y, "Carlini L2 " + str(confidence)))

            print("----------------------------------------------------------")
            print("Confidence:", confidence)
            all_pass, detector_breakdown = self.operator.filter(self.untrusted_data.data, thrs)
            both_acc, det_only_acc, ref_only_acc, none_acc = self.get_attack_acc(all_pass)
            print(detector_breakdown)
            both.append(both_acc)
            det_only.append(det_only_acc)
            ref_only.append(ref_only_acc)
            none.append(none_acc)

        size = 2.5

        print("With detector & reformer: ", both_acc)
        print("With detector: ",det_only_acc)
        print("With reformer: ", ref_only_acc)
        print("No Defense: ",none_acc)

        plt.plot(confs, none, c="green", label="No Defense", marker="x", markersize=size,alpha=0.5)
        plt.plot(confs, det_only, c="orange", label="With detector", marker="o", markersize=size,alpha=0.5)
        plt.plot(confs, ref_only, c="blue", label="With reformer", marker="^", markersize=size,alpha=0.5)
        plt.plot(confs, both, c="red", label="With detector & reformer", marker="s", markersize=size,alpha=0.5)

        pylab.legend(loc='lower left', bbox_to_anchor=(0.02, 0.1), prop={'size':8})
        plt.grid(linestyle='dotted')
        plt.xlabel(r"Confidence in Carlini $L^2$ attack")
        plt.ylabel("Classification accuracy")
        plt.xlim(min(confs)-1.0, max(confs)+1.0)
        plt.ylim(-0.05, 1.05)
        ax.yaxis.set_major_formatter(FuncFormatter('{0:.0%}'.format))

        save_path = os.path.join(self.graph_dir, graph_name+".pdf")
        plt.savefig(save_path)
        plt.clf()

    def print(self):
        return " ".join([self.operator.print(), self.untrusted_data.print()])

# %%
imgs_path = "attacked0.02_GTSRB/attacked/"
test_info = pd.read_csv("attacked0.02_GTSRB/predictions_test.csv")

data_list = []
original_labels_list = []
attacked_labels_list = []
label_dict = {0:3, 1:7, 2:9, 3:10, 4:11, 5:12, 6:13, 7:17, 8:18, 9:25, 10:35, 11:38} # mapping (fsgm 공격 이미지 라벨 0,1.2......) -> 실제 이미지 라벨 (3,7,9.....)

num = 0
for img in tqdm(os.listdir(imgs_path)[:1000]):
  im = Image.open(imgs_path+"/"+img)

  im = im.resize((32,32))
  im = np.array(im)
  im = im.reshape((3,32,32))
  im = im.transpose((1,2,0))
  # im = im.resize((32,32))
  # im = np.array(im)


  original_labels_list.append(label_dict[int(test_info[test_info['Unnamed: 0']==int(img[:-4])]['Original'])]) # 기존 label
  attacked_labels_list.append(label_dict[int(test_info[test_info['Unnamed: 0']==int(img[:-4])]['Attacked'])]) # 공격 label
  data_list.append(im/255)
        
attacked_data = np.array(data_list)
# attacked_data = (attacked_data.astype(np.float32) - 127.5) / 127.5

original_labels_list = np.array(original_labels_list)
attacked_labels_list = np.array(attacked_labels_list)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
original_labels_list2 = to_categorical(original_labels_list)
attacked_labels_list2 = to_categorical(attacked_labels_list)

# %%
import tensorflow as tf
import keras

keras.backend.set_learning_phase(False)
sess = keras.backend.get_session()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
classifier = Classifier("./models/example_classifier2")
loss, accuracy = classifier.model.evaluate(attacked_data, original_labels_list2)
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1733 - accuracy: 0.6340

# %%
loss, accuracy = classifier.model.evaluate(attacked_data, attacked_labels_list2)
# Out:
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2038 - accuracy: 0.5100

# %% [markdown]
# ## 1

# %%
DAE_detector_I = AEDetector("./defensive_models/0826_DAE_GTSRB_I", p=2)
DAE_detector_II = AEDetector("./defensive_models/0826_DAE_GTSRB_II", p=1)
DAE_reformer = SimpleReformer("./defensive_models/0826_DAE_GTSRB_II")


DAE_id_reformer = IdReformer()
DAE_classifier = Classifier("./models/example_classifier2")

DAE_detector_dict = dict()
DAE_detector_dict["I"] = DAE_detector_I
DAE_detector_dict["II"] = DAE_detector_II

# data = GTSRB()

dr = dict([("II"+str(i),.005) for i in range(100)]+[("JSD"+str(i),.01) for i in range(100)])

DAE_operator = Operator(data, DAE_classifier, DAE_detector_dict, DAE_reformer)
DAE_testAttack = AttackData(attacked_data, original_labels_list, "GTSRB FSGM")

DAE_evaluator = Evaluator(DAE_operator, DAE_testAttack)
DAE_evaluator.plot_various_confidences("defense_performance", drop_rate={"I": 0.001, "II": 0.001})
# Out:
# ==========================================================
# Drop Rate: {'I': 0.001, 'II': 0.001}
# Classification accuracy with all defense on: 0.0
# ----------------------------------------------------------
# Confidence: 0.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 10.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 20.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 30.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 40.0
# {'I': 0, 'II': 0}

# %%
DAE_evaluator = Evaluator(DAE_operator, DAE_testAttack)
DAE_evaluator.plot_various_confidences("defense_performance", drop_rate={"I": 0.001, "II": 0.001})
# Out:
# ==========================================================
# Drop Rate: {'I': 0.001, 'II': 0.001}
# Classification accuracy with all defense on: 0.0
# ----------------------------------------------------------
# Confidence: 0.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 10.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 20.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 30.0
# {'I': 0, 'II': 0}
# ----------------------------------------------------------
# Confidence: 40.0
# {'I': 0, 'II': 0}
# With detector & reformer:  1.0
# With detector:  1.0
# With reformer:  0.595
# No Defense:  0.634

# %%
print('with reformer')
predict = DAE_reformer.model.predict(attacked_data)
predicted = np.argmax(classifier.model.predict(predict),axis=1)
print(np.mean(predicted==original_labels_list))#,predicted)
# Out:
# with reformer
# 0.595

# %%
print('without reformer')
predicted = np.argmax(classifier.model.predict(attacked_data),axis=1)
print(np.mean(predicted==original_labels_list))#,predicted)
# Out:
# without reformer
# 0.634

# %% [markdown]
# ## 2

# %%
attacking = False

# prefix = "O_" 
# if attacking else ""

prefix = "0826_"

detector_I = []
detector_II = [AEDetector("./defensive_models/"+prefix+"PAE_GTSRB_II_"+str(i), p=1) for i in range(2)]
reformer = [SimpleReformer("./defensive_models/"+prefix+"PAE_GTSRB_II_"+str(i)) for i in range(2)]


# detector_I =[]
# detector_II = AEDetector("./defensive_models/"+prefix+"PAE_GTSRB_II_0", p=1)
# reformer = SimpleReformer("./defensive_models/"+prefix+"PAE_GTSRB_II_0")

id_reformer = IdReformer()
classifier = Classifier("./models/example_classifier2")

detector_JSD = [DBDetector(id_reformer, ref, classifier, T=10) for i,ref in enumerate(reformer)]
detector_JSD += [DBDetector(id_reformer, ref, classifier, T=40) for i,ref in enumerate(reformer)]


detector_dict = dict()
for i,det in enumerate(detector_I):
    detector_dict["I"+str(i)] = det
for i,det in enumerate(detector_II):
    detector_dict["II"+str(i)] = det
for i,det in enumerate(detector_JSD):
    detector_dict["JSD"+str(i)] = det

# data = GTSRB()

dr = dict([("II"+str(i),.005) for i in range(100)]+[("JSD"+str(i),.01) for i in range(100)])

detector_JSD = [DBDetector(id_reformer, ref, classifier, T=10) for i,ref in enumerate(reformer)]
detector_JSD += [DBDetector(id_reformer, ref, classifier, T=40) for i,ref in enumerate(reformer)]

# %%
operator = Operator(data, classifier, detector_dict, reformer[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-8dc4d336974f> in <module>
# ----> 1 operator = Operator(data, classifier, detector_dict, reformer[0])
#
# <ipython-input-59-9d5bfdaaef59> in __init__(self, data, classifier, det_dict, reformer)
#     164         self.det_dict = det_dict
#     165         self.reformer = reformer
# --> 166         self.normal = self.operate(AttackData(data.x_train, np.argmax(data.y_train, axis=1), "Normal"))
#     167
#     168
#
# <ipython-input-59-9d5bfdaaef59> in operate(self, untrusted_obj)
#     193         Y = np.argmax(self.classifier.classify(X), axis=1)
#     194         Y_judgement = (Y == Y_true[:len(X_prime)])
# --> 195         Y_prime = np.argmax(self.classifier.classify(X_prime), axis=1)
#     196         # print(Y_prime[:10])
#     197         # print(Y_true[:10])
#
# <ipython-input-59-9d5bfdaaef59> in classify(self, X, option, T)
#     138     def classify(self, X, option="logit", T=1):
#     139         if option == "logit":
# --> 140             return self.model.predict(X)
#     141         if option == "prob":
#     142             logits = self.model.predict(X)/T
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1801, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1790, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1783, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1751, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 32, 32, 3), found shape=(None, 546, 32, 32, 3)

# %%
testAttack = AttackData(attacked_data, original_labels_list, "GTSRB FSGM")

# %%
evaluator = Evaluator(operator, testAttack)
evaluator.plot_various_confidences("defense_performance", drop_rate={"I": 0.001, "II": 0.001})

# %%
print('with reformer')
predict = reformer[0].model.predict(attacked_data)
predicted = np.argmax(classifier.model.predict(predict),axis=1)
print(np.mean(predicted==original_labels_list))#,predicted)
# Out:
# with reformer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-04403569b2f8> in <module>
#       1 print('with reformer')
#       2 predict = reformer[0].model.predict(attacked_data)
# ----> 3 predicted = np.argmax(classifier.model.predict(predict),axis=1)
#       4 print(np.mean(predicted==original_labels_list))#,predicted)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1801, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1790, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1783, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1751, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py", line 200, in assert_input_compatibility
#         raise ValueError(f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#
#     ValueError: Layer "sequential" expects 1 input(s), but it received 4 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(None, 32, 32, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 32, 32, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:2' shape=(None, 32, 32, 3) dtype=float32>, <tf.Tensor 'IteratorGetNext:3' shape=(None, 32, 32, 3) dtype=float32>]
