# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Utils

# %%
import pickle
import os
import numpy as np


def prepare_data(dataset, idx):
    """
    Extract data from index.
    dataset: Full, working dataset. Such as MNIST().
    idx: Index of test examples that we care about.
    return: X, targets, Y
    """
    return dataset.test_data[idx], dataset.test_labels[idx], np.argmax(dataset.test_labels[idx], axis=1)


def save_obj(obj, name, directory='./attack_data/'):
    with open(os.path.join(directory, name + '.pkl'), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)


def load_obj(name, directory='./attack_data/'):
    if name.endswith(".pkl"): name = name[:-4]
    with open(os.path.join(directory, name + '.pkl'), 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# worker

# %%
import matplotlib
matplotlib.use('Agg')
from scipy.stats import entropy
from numpy.linalg import norm
from matplotlib.ticker import FuncFormatter
from keras.models import Sequential, load_model
from keras.activations import softmax
from keras.layers import Lambda
import numpy as np
import pylab
import os
import matplotlib.pyplot as plt


class AEDetector:
    def __init__(self, path, p=1):
        """
        Error based detector.
        Marks examples for filtering decisions.
        path: Path to the autoencoder used.
        p: Distance measure to use.
        """
        self.model = load_model(path)
        self.path = path
        self.p = p

    def mark(self, X):
        diff = np.abs(X - self.model.predict(X))
        marks = np.mean(np.power(diff, self.p), axis=(1,2,3))
        return marks

    def print(self):
        return "AEDetector:" + self.path.split("/")[-1]


class IdReformer:
    def __init__(self, path="IdentityFunction"):
        """
        Identity reformer.
        Reforms an example to itself.
        """
        self.path = path
        self.heal = lambda X: X

    def print(self):
        return "IdReformer:" + self.path


class SimpleReformer:
    def __init__(self, path):
        """
        Reformer.
        Reforms examples with autoencoder. Action of reforming is called heal.
        path: Path to the autoencoder used.
        """
        self.model = load_model(path)
        self.path = path

    def heal(self, X):
        X = self.model.predict(X)
        return np.clip(X, 0.0, 1.0)

    def print(self):
        return "SimpleReformer:" + self.path.split("/")[-1]


def JSD(P, Q):
    _P = P / norm(P, ord=1)
    _Q = Q / norm(Q, ord=1)
    _M = 0.5 * (_P + _Q)
    return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))


class DBDetector:
    def __init__(self, reconstructor, prober, classifier, option="jsd", T=1):
        """
        Divergence-Based Detector.
        reconstructor: One autoencoder.
        prober: Another autoencoder.
        classifier: Classifier object.
        option: Measure of distance, jsd as default.
        T: Temperature to soften the classification decision.
        """
        self.prober = prober
        self.reconstructor = reconstructor
        self.classifier = classifier
        self.option = option
        self.T = T

    def mark(self, X):
        return self.mark_jsd(X)

    def mark_jsd(self, X):
        Xp = self.prober.heal(X)
        Xr = self.reconstructor.heal(X)
        Pp = self.classifier.classify(Xp, option="prob", T=self.T)
        Pr = self.classifier.classify(Xr, option="prob", T=self.T)

        marks = [(JSD(Pp[i], Pr[i])) for i in range(len(Pr))]
        return np.array(marks)

    def print(self):
        return "Divergence-Based Detector"


class Classifier:
    def __init__(self, classifier_path):
        """
        Keras classifier wrapper.
        Note that the wrapped classifier should spit logits as output.
        classifier_path: Path to Keras classifier file.
        """
        self.path = classifier_path
        self.model = load_model(classifier_path, compile=False)
        self.softmax = Sequential()
        self.softmax.add(Lambda(lambda X: softmax(X, axis=1), input_shape=(10,)))

    def classify(self, X, option="logit", T=1):
        if option == "logit":
            return self.model.predict(X)
        if option == "prob":
            logits = self.model.predict(X)/T
            return self.softmax.predict(logits)

    def print(self):
        return "Classifier:"+self.path.split("/")[-1]


class Operator:
    def __init__(self, data, classifier, det_dict, reformer):
        """
        Operator.
        Describes the classification problem and defense.
        data: Standard problem dataset. Including train, test, and validation.
        classifier: Target classifier.
        reformer: Reformer of defense.
        det_dict: Detector(s) of defense.
        """
        self.data = data
        self.classifier = classifier
        self.det_dict = det_dict
        self.reformer = reformer
        self.normal = self.operate(AttackData(self.data.test_data,
                        np.argmax(self.data.test_labels, axis=1), "Normal"))

    def get_thrs(self, drop_rate):
        """
        Get filtering threshold by marking validation set.
        """
        thrs = dict()
        for name, detector in self.det_dict.items():
            num = int(len(self.data.validation_data) * drop_rate[name])
            marks = detector.mark(self.data.validation_data)
            marks = np.sort(marks)
            thrs[name] = marks[-num]
        return thrs

    def operate(self, untrusted_obj):
        """
        For untrusted input(normal or adversarial), classify original input and
        reformed input. Classifier is unaware of the source of input.
        untrusted_obj: Input data.
        """
        X = untrusted_obj.data
        Y_true = untrusted_obj.labels

        X_prime = self.reformer.heal(X)
        Y = np.argmax(self.classifier.classify(X), axis=1)
        Y_judgement = (Y == Y_true[:len(X_prime)])
        Y_prime = np.argmax(self.classifier.classify(X_prime), axis=1)
        Y_prime_judgement = (Y_prime == Y_true[:len(X_prime)])

        return np.array(list(zip(Y_judgement, Y_prime_judgement)))

    def filter(self, X, thrs):
        """
        untrusted_obj: Untrusted input to test against.
        thrs: Thresholds.
        return:
        all_pass: Index of examples that passed all detectors.
        collector: Number of examples that escaped each detector.
        """
        collector = dict()
        all_pass = np.array(range(10000))
        for name, detector in self.det_dict.items():
            marks = detector.mark(X)
            idx_pass = np.argwhere(marks < thrs[name])
            collector[name] = len(idx_pass)
            all_pass = np.intersect1d(all_pass, idx_pass)
        return all_pass, collector

    def print(self):
        components = [self.reformer, self.classifier]
        return " ".join(map(lambda obj: getattr(obj, "print")(), components))


class AttackData:
    def __init__(self, examples, labels, name=""):
        """
        Input data wrapper. May be normal or adversarial.
        examples: Path or object of input examples.
        labels: Ground truth labels.
        """
        if isinstance(examples, str): self.data = load_obj(examples)
        else: self.data = examples
        self.labels = labels
        self.name = name

    def print(self):
        return "Attack:"+self.name


class Evaluator:
    def __init__(self, operator, untrusted_data, graph_dir="./graph"):
        """
        Evaluator.
        For strategy described by operator, conducts tests on untrusted input.
        Mainly stats and plotting code. Most methods omitted for clarity.
        operator: Operator object.
        untrusted_data: Input data to test against.
        graph_dir: Where to spit the graphs.
        """
        self.operator = operator
        self.untrusted_data = untrusted_data
        self.graph_dir = graph_dir
        self.data_package = operator.operate(untrusted_data)

    def bind_operator(self, operator):
        self.operator = operator
        self.data_package = operator.operate(self.untrusted_data)

    def load_data(self, data):
        self.untrusted_data = data
        self.data_package = self.operator.operate(self.untrusted_data)

    def get_normal_acc(self, normal_all_pass):
        """
        Break down of who does what in defense. Accuracy of defense on normal
        input.
        both: Both detectors and reformer take effect
        det_only: detector(s) take effect
        ref_only: Only reformer takes effect
        none: Attack effect with no defense
        """
        normal_tups = self.operator.normal
        num_normal = len(normal_tups)
        filtered_normal_tups = normal_tups[normal_all_pass]

        both_acc = sum(1 for _, XpC in filtered_normal_tups if XpC)/num_normal
        det_only_acc = sum(1 for XC, XpC in filtered_normal_tups if XC)/num_normal
        ref_only_acc = sum([1 for _, XpC in normal_tups if XpC])/num_normal
        none_acc = sum([1 for XC, _ in normal_tups if XC])/num_normal

        return both_acc, det_only_acc, ref_only_acc, none_acc

    def get_attack_acc(self, attack_pass):
        attack_tups = self.data_package
        num_untrusted = len(attack_tups)
        filtered_attack_tups = attack_tups[attack_pass]

        both_acc = 1 - sum(1 for _, XpC in filtered_attack_tups if not XpC)/num_untrusted
        det_only_acc = 1 - sum(1 for XC, XpC in filtered_attack_tups if not XC)/num_untrusted
        ref_only_acc = sum([1 for _, XpC in attack_tups if XpC])/num_untrusted
        none_acc = sum([1 for XC, _ in attack_tups if XC])/num_untrusted
        return both_acc, det_only_acc, ref_only_acc, none_acc

    def plot_various_confidences(self, graph_name, drop_rate,
                                 idx_file="example_idx",
                                 confs=(0.0, 10.0, 20.0, 30.0, 40.0),
                                 get_attack_data_name=lambda c: "example_carlini_"+str(c)):
        """
        Test defense performance against Carlini L2 attack of various confidences.
        graph_name: Name of graph file.
        drop_rate: How many normal examples should each detector drops?
        idx_file: Index of adversarial examples in standard test set.
        confs: A series of confidence to test against.
        get_attack_data_name: Function mapping confidence to corresponding file.
        """
        pylab.rcParams['figure.figsize'] = 6, 4
        fig = plt.figure(1, (6, 4))
        ax = fig.add_subplot(1, 1, 1)

        idx = load_obj(idx_file)
        X, _, Y = prepare_data(self.operator.data, idx)

        det_only = []
        ref_only = []
        both = []
        none = []

        print("\n==========================================================")
        print("Drop Rate:", drop_rate)
        thrs = self.operator.get_thrs(drop_rate)

        all_pass, _ = self.operator.filter(self.operator.data.test_data, thrs)
        all_on_acc, _, _, _ = self.get_normal_acc(all_pass)

        print("Classification accuracy with all defense on:", all_on_acc)

        for confidence in confs:
            f = get_attack_data_name(confidence)
            self.load_data(AttackData(f, Y, "Carlini L2 " + str(confidence)))

            print("----------------------------------------------------------")
            print("Confidence:", confidence)
            all_pass, detector_breakdown = self.operator.filter(self.untrusted_data.data, thrs)
            both_acc, det_only_acc, ref_only_acc, none_acc = self.get_attack_acc(all_pass)
            print(detector_breakdown)
            both.append(both_acc)
            det_only.append(det_only_acc)
            ref_only.append(ref_only_acc)
            none.append(none_acc)

        size = 2.5
        plt.plot(confs, none, c="green", label="No fefense", marker="x", markersize=size)
        plt.plot(confs, det_only, c="orange", label="With detector", marker="o", markersize=size)
        plt.plot(confs, ref_only, c="blue", label="With reformer", marker="^", markersize=size)
        plt.plot(confs, both, c="red", label="With detector & reformer", marker="s", markersize=size)

        pylab.legend(loc='lower left', bbox_to_anchor=(0.02, 0.1), prop={'size':8})
        plt.grid(linestyle='dotted')
        plt.xlabel(r"Confidence in Carlini $L^2$ attack")
        plt.ylabel("Classification accuracy")
        plt.xlim(min(confs)-1.0, max(confs)+1.0)
        plt.ylim(-0.05, 1.05)
        ax.yaxis.set_major_formatter(FuncFormatter('{0:.0%}'.format))

        save_path = os.path.join(self.graph_dir, graph_name+".pdf")
        plt.savefig(save_path)
        plt.clf()

    def print(self):
        return " ".join([self.operator.print(), self.untrusted_data.print()])

# %% [markdown]
# setup_mnist

# %%
import numpy as np
import os
import gzip
import urllib.request

from keras.models import load_model

def extract_data(filename, num_images):
    with gzip.open(filename) as bytestream:
        bytestream.read(16)
        buf = bytestream.read(num_images*28*28)
        data = np.frombuffer(buf, dtype=np.uint8).astype(np.float32)
        data = (data / 255) - 0.5
        data = data.reshape(num_images, 28, 28, 1)
        return data

def extract_labels(filename, num_images):
    with gzip.open(filename) as bytestream:
        bytestream.read(8)
        buf = bytestream.read(1 * num_images)
        labels = np.frombuffer(buf, dtype=np.uint8)
    return (np.arange(10) == labels[:, None]).astype(np.float32)

class MNIST:
    def __init__(self):
        if not os.path.exists("data"):
            os.mkdir("data")
            files = ["train-images-idx3-ubyte.gz",
                     "t10k-images-idx3-ubyte.gz",
                     "train-labels-idx1-ubyte.gz",
                     "t10k-labels-idx1-ubyte.gz"]
            for name in files:
                urllib.request.urlretrieve('http://yann.lecun.com/exdb/mnist/' + name, "data/"+name)

        train_data = extract_data("data/train-images-idx3-ubyte.gz", 60000)+0.5
        train_labels = extract_labels("data/train-labels-idx1-ubyte.gz", 60000)
        self.test_data = extract_data("data/t10k-images-idx3-ubyte.gz", 10000)+0.5
        self.test_labels = extract_labels("data/t10k-labels-idx1-ubyte.gz", 10000)
        
        VALIDATION_SIZE = 5000
        
        self.validation_data = train_data[:VALIDATION_SIZE, :, :, :]
        self.validation_labels = train_labels[:VALIDATION_SIZE]
        self.train_data = train_data[VALIDATION_SIZE:, :, :, :]
        self.train_labels = train_labels[VALIDATION_SIZE:]

    @staticmethod
    def print():
        return "MNIST"


class MNISTModel:
    def __init__(self, restore, session=None):
        self.num_channels = 1
        self.image_size = 28
        self.num_labels = 10
        self.model = load_model(restore)

    def predict(self, data):
        return self.model(data)

# %% [markdown]
# defensive_models

# %%
import os
import numpy as np
from keras.layers.core import Lambda
from keras.layers.merge import Average, add
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, AveragePooling2D
from keras.models import Model
import keras.regularizers as regs


class DenoisingAutoEncoder:
    def __init__(self, image_shape,
                 structure,
                 v_noise=0.0,
                 activation="relu",
                 model_dir="./defensive_models/",
                 reg_strength=0.0):
        """
        Denoising autoencoder.
        image_shape: Shape of input image. e.g. 28, 28, 1.
        structure: Structure of autoencoder.
        v_noise: Volume of noise while training.
        activation: What activation function to use.
        model_dir: Where to save / load model from.
        reg_strength: Strength of L2 regularization.
        """
        h, w, c = image_shape
        self.image_shape = image_shape
        self.model_dir = model_dir
        self.v_noise = v_noise

        input_img = Input(shape=self.image_shape)
        x = input_img

        for layer in structure:
            if isinstance(layer, int):
                x = Conv2D(layer, (3, 3), activation=activation, padding="same",
                           activity_regularizer=regs.l2(reg_strength))(x)
            elif layer == "max":
                x = MaxPooling2D((2, 2), padding="same")(x)
            elif layer == "average":
                x = AveragePooling2D((2, 2), padding="same")(x)
            else:
                print(layer, "is not recognized!")
                exit(0)

        for layer in reversed(structure):
            if isinstance(layer, int):
                x = Conv2D(layer, (3, 3), activation=activation, padding="same",
                           activity_regularizer=regs.l2(reg_strength))(x)
            elif layer == "max" or layer == "average":
                x = UpSampling2D((2, 2))(x)

        decoded = Conv2D(c, (3, 3), activation='sigmoid', padding='same',
                         activity_regularizer=regs.l2(reg_strength))(x)
        self.model = Model(input_img, decoded)

    def train(self, data, archive_name, num_epochs=100, batch_size=256,
              if_save=True):
        self.model.compile(loss='mean_squared_error',
                           metrics=['mean_squared_error'],
                           optimizer='adam')

        noise = self.v_noise * np.random.normal(size=np.shape(data.train_data))
        noisy_train_data = data.train_data + noise
        noisy_train_data = np.clip(noisy_train_data, 0.0, 1.0)

        self.model.fit(noisy_train_data, data.train_data,
                       batch_size=batch_size,
                       validation_data=(data.validation_data, data.validation_data),
                       epochs=num_epochs,
                       shuffle=True)

        if if_save: self.model.save(os.path.join(self.model_dir, archive_name))

    def load(self, archive_name, model_dir=None):
        if model_dir is None: model_dir = self.model_dir
        self.model.load_weights(os.path.join(model_dir, archive_name))


class PackedAutoEncoder:
    def __init__(self, image_shape, structure, data,
                 v_noise=0.1, n_pack=2, pre_epochs=3, activation="relu",
                 model_dir="./defensive_models/"):
        """
        Train different autoencoders.
        Demo code for graybox scenario.
        pre_epochs: How many epochs do we train before fine-tuning.
        n_pack: Number of autoencoders we want to train at once.
        """
        self.v_noise = v_noise
        self.n_pack = n_pack
        self.model_dir = model_dir
        pack = []

        for i in range(n_pack):
            dae = DenoisingAutoEncoder(image_shape, structure, v_noise=v_noise,
                                       activation=activation, model_dir=model_dir)
            dae.train(data, "", if_save=False, num_epochs=pre_epochs)
            pack.append(dae.model)

        shared_input = Input(shape=image_shape, name="shared_input")
        outputs = [dae(shared_input) for dae in pack]
        avg_output = Average()(outputs)
        delta_outputs = [add([avg_output, Lambda(lambda x: -x)(output)])
                         for output in outputs]

        self.model = Model(inputs=shared_input, outputs=outputs+delta_outputs)

    def train(self, data, archive_name, alpha, num_epochs=10, batch_size=128):
        noise = self.v_noise * np.random.normal(size=np.shape(data.train_data))
        noisy_train_data = data.train_data + noise
        noisy_train_data = np.clip(noisy_train_data, 0.0, 1.0)

        train_zeros = [np.zeros_like(data.train_data)] * self.n_pack
        val_zeros = [np.zeros_like(data.validation_data)] * self.n_pack

        self.model.compile(loss="mean_squared_error", optimizer="adam",
                           loss_weights=[1.0]*self.n_pack + [-alpha]*self.n_pack)

        self.model.fit(noisy_train_data,
                       [data.train_data]*self.n_pack + train_zeros,
                       batch_size=batch_size,
                       validation_data=(data.validation_data,
                            [data.validation_data]*self.n_pack+val_zeros),
                       epochs=num_epochs,
                       shuffle=True)

        for i in range(self.n_pack):
            model = Model(self.model.input, self.model.outputs[i])
            model.save(os.path.join(self.model_dir, archive_name+"_"+str(i)))

    def load(self, archive_name, model_dir=None):
        if model_dir is None: model_dir = self.model_dir
        self.model.load_weights(os.path.join(model_dir, archive_name))

# %% [markdown]
# train_models

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
import os


def train(data, file_name, params, num_epochs=50, batch_size=128):
    """
    Standard neural network training procedure.
    """
    model = Sequential()

    model.add(Conv2D(params[0], (3, 3), input_shape=data.train_data.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(params[1], (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(params[2], (3, 3)))
    model.add(Activation('relu'))
    model.add(Conv2D(params[3], (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(params[4]))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(params[5]))
    model.add(Activation('relu'))
    model.add(Dense(10))

    def fn(correct, predicted):
        return tf.nn.softmax_cross_entropy_with_logits(labels=correct,
                                                       logits=predicted)

    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

    model.compile(loss=fn,
                  optimizer=sgd,
                  metrics=['accuracy'])

    model.fit(data.train_data, data.train_labels,
              batch_size=batch_size,
              validation_data=(data.validation_data, data.validation_labels),
              epochs=num_epochs,
              shuffle=True,)

    if file_name != None:
        model.save(file_name)

    return model


if not os.path.isdir('models'):
    os.makedirs('models')

train(MNIST(), "models/example_classifier", [32, 32, 64, 64, 200, 200],
      num_epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 430/430 [==============================] - 117s 271ms/step - loss: 0.5015 - accuracy: 0.8369 - val_loss: 0.0884 - val_accuracy: 0.9716
# Epoch 2/10
# 430/430 [==============================] - 117s 272ms/step - loss: 0.1209 - accuracy: 0.9645 - val_loss: 0.0620 - val_accuracy: 0.9832
# Epoch 3/10
# 430/430 [==============================] - 117s 273ms/step - loss: 0.0866 - accuracy: 0.9738 - val_loss: 0.0509 - val_accuracy: 0.9858
# Epoch 4/10
# 430/430 [==============================] - 117s 272ms/step - loss: 0.0695 - accuracy: 0.9789 - val_loss: 0.0466 - val_accuracy: 0.9882
# Epoch 5/10
# 430/430 [==============================] - 116s 270ms/step - loss: 0.0585 - accuracy: 0.9823 - val_loss: 0.0396 - val_accuracy: 0.9894
# Epoch 6/10
# 430/430 [==============================] - 116s 271ms/step - loss: 0.0516 - accuracy: 0.9850 - val_loss: 0.0358 - val_accuracy: 0.9900
# Epoch 7/10
# 430/430 [==============================] - 117s 273ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 0.0386 - val_accuracy: 0.9886
# Epoch 8/10
# 430/430 [==============================] - 118s 275ms/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 0.0351 - val_accuracy: 0.9910
# Epoch 9/10
# 430/430 [==============================] - 119s 277ms/step - loss: 0.0382 - accuracy: 0.9886 - val_loss: 0.0345 - val_accuracy: 0.9902
# Epoch 10/10
# 430/430 [==============================] - 116s 270ms/step - loss: 0.0347 - accuracy: 0.9898 - val_loss: 0.0336 - val_accuracy: 0.9918

# %% [markdown]
# train_defense

# %%
DAE = DenoisingAutoEncoder

poolings = ["average", "max"]

shape = [28, 28, 1]
combination_I = [3, "average", 3]
combination_II = [3]
activation = "sigmoid"
reg_strength = 1e-9
epochs = 100

data = MNIST()

AE_I = DAE(shape, combination_I, v_noise=0.1, activation=activation,
           reg_strength=reg_strength)
AE_I.train(data, "MNIST_I", num_epochs=epochs)

AE_II = DAE(shape, combination_II, v_noise=0.1, activation=activation,
            reg_strength=reg_strength)
AE_II.train(data, "MNIST_II", num_epochs=epochs)
# Out:
# Epoch 1/100
# 215/215 [==============================] - 48s 219ms/step - loss: 0.1628 - mean_squared_error: 0.1628 - val_loss: 0.1076 - val_mean_squared_error: 0.1076
# Epoch 2/100
# 215/215 [==============================] - 48s 226ms/step - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.1020 - val_mean_squared_error: 0.1020
# Epoch 3/100
# 215/215 [==============================] - 45s 212ms/step - loss: 0.1017 - mean_squared_error: 0.1017 - val_loss: 0.1009 - val_mean_squared_error: 0.1009
# Epoch 4/100
# 215/215 [==============================] - 48s 224ms/step - loss: 0.1009 - mean_squared_error: 0.1009 - val_loss: 0.1002 - val_mean_squared_error: 0.1002
# Epoch 5/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.1003 - mean_squared_error: 0.1003 - val_loss: 0.0995 - val_mean_squared_error: 0.0995
# Epoch 6/100
# 215/215 [==============================] - 47s 218ms/step - loss: 0.0995 - mean_squared_error: 0.0995 - val_loss: 0.0987 - val_mean_squared_error: 0.0987
# Epoch 7/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0986 - mean_squared_error: 0.0986 - val_loss: 0.0977 - val_mean_squared_error: 0.0977
# Epoch 8/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.0975 - mean_squared_error: 0.0975 - val_loss: 0.0965 - val_mean_squared_error: 0.0965
# Epoch 9/100
# 215/215 [==============================] - 47s 220ms/step - loss: 0.0963 - mean_squared_error: 0.0963 - val_loss: 0.0953 - val_mean_squared_error: 0.0953
# Epoch 10/100
# 215/215 [==============================] - 46s 213ms/step - loss: 0.0950 - mean_squared_error: 0.0950 - val_loss: 0.0939 - val_mean_squared_error: 0.0939
# Epoch 11/100
# 215/215 [==============================] - 46s 215ms/step - loss: 0.0935 - mean_squared_error: 0.0935 - val_loss: 0.0921 - val_mean_squared_error: 0.0921
# Epoch 12/100
# 215/215 [==============================] - 49s 226ms/step - loss: 0.0907 - mean_squared_error: 0.0907 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Epoch 13/100
# 215/215 [==============================] - 46s 213ms/step - loss: 0.0558 - mean_squared_error: 0.0558 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 14/100
# 215/215 [==============================] - 47s 217ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 15/100
# 215/215 [==============================] - 49s 227ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 16/100
# 215/215 [==============================] - 47s 217ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 17/100
# 215/215 [==============================] - 49s 228ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 18/100
# 215/215 [==============================] - 48s 222ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 19/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 20/100
# 215/215 [==============================] - 48s 224ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 21/100
# 215/215 [==============================] - 47s 221ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 22/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 23/100
# 215/215 [==============================] - 48s 223ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 24/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 25/100
# 215/215 [==============================] - 47s 217ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 26/100
# 215/215 [==============================] - 47s 216ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 27/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 28/100
# 215/215 [==============================] - 47s 218ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 29/100
# 215/215 [==============================] - 49s 228ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 30/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 31/100
# 215/215 [==============================] - 47s 217ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 32/100
# 215/215 [==============================] - 49s 227ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 33/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 34/100
# 215/215 [==============================] - 49s 228ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 35/100
# 215/215 [==============================] - 46s 216ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 36/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 37/100
# 215/215 [==============================] - 47s 220ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 38/100
# 215/215 [==============================] - 47s 220ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 39/100
# 215/215 [==============================] - 48s 225ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 40/100
# 215/215 [==============================] - 47s 220ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 41/100
# 215/215 [==============================] - 48s 224ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 42/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 43/100
# 215/215 [==============================] - 47s 219ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 44/100
# 215/215 [==============================] - 49s 228ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 45/100
# 215/215 [==============================] - 46s 215ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 46/100
# 215/215 [==============================] - 49s 226ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 47/100
# 215/215 [==============================] - 47s 220ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 48/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 49/100
# 215/215 [==============================] - 52s 243ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 50/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 51/100
# 215/215 [==============================] - 51s 240ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 52/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 53/100
# 215/215 [==============================] - 51s 238ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 54/100
# 215/215 [==============================] - 49s 228ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 55/100
# 215/215 [==============================] - 51s 238ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 56/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 57/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 58/100
# 215/215 [==============================] - 51s 238ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 59/100
# 215/215 [==============================] - 49s 227ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 60/100
# 215/215 [==============================] - 51s 238ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 61/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 62/100
# 215/215 [==============================] - 52s 240ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 63/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 64/100
# 215/215 [==============================] - 51s 239ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 65/100
# 215/215 [==============================] - 50s 230ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 66/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 67/100
# 215/215 [==============================] - 52s 240ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 68/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 69/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 70/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 71/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 72/100
# 215/215 [==============================] - 49s 230ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 73/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 74/100
# 215/215 [==============================] - 50s 235ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 75/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 76/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0024 - mean_squared_error: 0.0023 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 77/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 78/100
# 215/215 [==============================] - 49s 229ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 79/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 80/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 81/100
# 215/215 [==============================] - 51s 237ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 82/100
# 215/215 [==============================] - 50s 234ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 83/100
# 215/215 [==============================] - 50s 234ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 84/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 85/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 86/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 87/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 88/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 89/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 90/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 91/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 92/100
# 215/215 [==============================] - 50s 230ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 93/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 94/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 95/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 96/100
# 215/215 [==============================] - 50s 231ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 97/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 98/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 99/100
# 215/215 [==============================] - 50s 232ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 100/100
# 215/215 [==============================] - 50s 233ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# INFO:tensorflow:Assets written to: ./defensive_models/MNIST_I/assets
# Epoch 1/100
# 215/215 [==============================] - 40s 181ms/step - loss: 0.1404 - mean_squared_error: 0.1404 - val_loss: 0.0889 - val_mean_squared_error: 0.0889
# Epoch 2/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0821 - mean_squared_error: 0.0821 - val_loss: 0.0721 - val_mean_squared_error: 0.0721
# Epoch 3/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0628 - mean_squared_error: 0.0628 - val_loss: 0.0490 - val_mean_squared_error: 0.0490
# Epoch 4/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 5/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 6/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 7/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 8/100
# 215/215 [==============================] - 39s 179ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0114 - val_mean_squared_error: 0.0114
# Epoch 9/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 10/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 11/100
# 215/215 [==============================] - 38s 179ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 12/100
# 215/215 [==============================] - 38s 179ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 13/100
# 215/215 [==============================] - 39s 179ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 14/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 15/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 16/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0050 - mean_squared_error: 0.0049 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 17/100
# 215/215 [==============================] - 39s 182ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 18/100
# 215/215 [==============================] - 39s 183ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 19/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 20/100
# 215/215 [==============================] - 38s 179ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 21/100
# 215/215 [==============================] - 39s 183ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 22/100
# 215/215 [==============================] - 40s 187ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 23/100
# 215/215 [==============================] - 40s 187ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 24/100
# 215/215 [==============================] - 40s 188ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 25/100
# 215/215 [==============================] - 41s 192ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 26/100
# 215/215 [==============================] - 40s 184ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 27/100
# 215/215 [==============================] - 40s 184ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 28/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 29/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 30/100
# 215/215 [==============================] - 39s 179ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 31/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 32/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 33/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 34/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 35/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 9.7273e-04 - val_mean_squared_error: 9.7017e-04
# Epoch 36/100
# 215/215 [==============================] - 38s 178ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 9.2366e-04 - val_mean_squared_error: 9.2110e-04
# Epoch 37/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.8019e-04 - val_mean_squared_error: 8.7764e-04
# Epoch 38/100
# 215/215 [==============================] - 39s 179ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.4930e-04 - val_mean_squared_error: 8.4676e-04
# Epoch 39/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.1324e-04 - val_mean_squared_error: 8.1070e-04
# Epoch 40/100
# 215/215 [==============================] - 39s 179ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.8422e-04 - val_mean_squared_error: 7.8168e-04
# Epoch 41/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.5382e-04 - val_mean_squared_error: 7.5129e-04
# Epoch 42/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.2999e-04 - val_mean_squared_error: 7.2746e-04
# Epoch 43/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.0531e-04 - val_mean_squared_error: 7.0278e-04
# Epoch 44/100
# 215/215 [==============================] - 39s 182ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.8256e-04 - val_mean_squared_error: 6.8003e-04
# Epoch 45/100
# 215/215 [==============================] - 39s 183ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.5984e-04 - val_mean_squared_error: 6.5731e-04
# Epoch 46/100
# 215/215 [==============================] - 40s 186ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.4375e-04 - val_mean_squared_error: 6.4122e-04
# Epoch 47/100
# 215/215 [==============================] - 39s 182ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.2514e-04 - val_mean_squared_error: 6.2261e-04
# Epoch 48/100
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.1122e-04 - val_mean_squared_error: 6.0868e-04
# Epoch 49/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.9755e-04 - val_mean_squared_error: 5.9501e-04
# Epoch 50/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.8521e-04 - val_mean_squared_error: 5.8267e-04
# Epoch 51/100
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.7590e-04 - val_mean_squared_error: 5.7335e-04
# Epoch 52/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.6706e-04 - val_mean_squared_error: 5.6450e-04
# Epoch 53/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.5953e-04 - val_mean_squared_error: 5.5697e-04
# Epoch 54/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.5072e-04 - val_mean_squared_error: 5.4814e-04
# Epoch 55/100
# 215/215 [==============================] - 37s 174ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.4294e-04 - val_mean_squared_error: 5.4035e-04
# Epoch 56/100
# 215/215 [==============================] - 37s 172ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 5.3614e-04 - val_mean_squared_error: 5.3353e-04
# Epoch 57/100
# 215/215 [==============================] - 37s 172ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.2993e-04 - val_mean_squared_error: 5.2731e-04
# Epoch 58/100
# 215/215 [==============================] - 37s 170ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.2565e-04 - val_mean_squared_error: 5.2302e-04
# Epoch 59/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.1825e-04 - val_mean_squared_error: 5.1561e-04
# Epoch 60/100
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.1249e-04 - val_mean_squared_error: 5.0984e-04
# Epoch 61/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.0763e-04 - val_mean_squared_error: 5.0496e-04
# Epoch 62/100
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.0317e-04 - val_mean_squared_error: 5.0049e-04
# Epoch 63/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.9741e-04 - val_mean_squared_error: 4.9471e-04
# Epoch 64/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.9228e-04 - val_mean_squared_error: 4.8958e-04
# Epoch 65/100
# 215/215 [==============================] - 36s 167ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.8922e-04 - val_mean_squared_error: 4.8650e-04
# Epoch 66/100
# 215/215 [==============================] - 35s 163ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.8612e-04 - val_mean_squared_error: 4.8339e-04
# Epoch 67/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.8259e-04 - val_mean_squared_error: 4.7985e-04
# Epoch 68/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.7906e-04 - val_mean_squared_error: 4.7630e-04
# Epoch 69/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.7576e-04 - val_mean_squared_error: 4.7299e-04
# Epoch 70/100
# 215/215 [==============================] - 35s 164ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.7076e-04 - val_mean_squared_error: 4.6799e-04
# Epoch 71/100
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.6732e-04 - val_mean_squared_error: 4.6454e-04
# Epoch 72/100
# 215/215 [==============================] - 37s 172ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.6642e-04 - val_mean_squared_error: 4.6363e-04
# Epoch 73/100
# 215/215 [==============================] - 36s 167ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.6262e-04 - val_mean_squared_error: 4.5982e-04
# Epoch 74/100
# 215/215 [==============================] - 36s 165ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.6135e-04 - val_mean_squared_error: 4.5854e-04
# Epoch 75/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.5562e-04 - val_mean_squared_error: 4.5280e-04
# Epoch 76/100
# 215/215 [==============================] - 37s 171ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.5675e-04 - val_mean_squared_error: 4.5393e-04
# Epoch 77/100
# 215/215 [==============================] - 37s 174ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4997e-04 - val_mean_squared_error: 4.4713e-04
# Epoch 78/100
# 215/215 [==============================] - 40s 184ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4921e-04 - val_mean_squared_error: 4.4637e-04
# Epoch 79/100
# 215/215 [==============================] - 37s 172ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4586e-04 - val_mean_squared_error: 4.4301e-04
# Epoch 80/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4449e-04 - val_mean_squared_error: 4.4163e-04
# Epoch 81/100
# 215/215 [==============================] - 38s 178ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4387e-04 - val_mean_squared_error: 4.4101e-04
# Epoch 82/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3722e-04 - val_mean_squared_error: 4.3435e-04
# Epoch 83/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3438e-04 - val_mean_squared_error: 4.3151e-04
# Epoch 84/100
# 215/215 [==============================] - 38s 177ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.4134e-04 - val_mean_squared_error: 4.3847e-04
# Epoch 85/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3307e-04 - val_mean_squared_error: 4.3019e-04
# Epoch 86/100
# 215/215 [==============================] - 37s 173ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3062e-04 - val_mean_squared_error: 4.2774e-04
# Epoch 87/100
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3070e-04 - val_mean_squared_error: 4.2781e-04
# Epoch 88/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.3360e-04 - val_mean_squared_error: 4.3071e-04
# Epoch 89/100
# 215/215 [==============================] - 39s 181ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.2476e-04 - val_mean_squared_error: 4.2187e-04
# Epoch 90/100
# 215/215 [==============================] - 37s 174ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.2488e-04 - val_mean_squared_error: 4.2199e-04
# Epoch 91/100
# 215/215 [==============================] - 37s 174ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.2114e-04 - val_mean_squared_error: 4.1824e-04
# Epoch 92/100
# 215/215 [==============================] - 39s 183ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 4.2130e-04 - val_mean_squared_error: 4.1841e-04
# Epoch 93/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 4.2189e-04 - val_mean_squared_error: 4.1899e-04
# Epoch 94/100
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1519e-04 - val_mean_squared_error: 4.1229e-04
# Epoch 95/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1763e-04 - val_mean_squared_error: 4.1473e-04
# Epoch 96/100
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1622e-04 - val_mean_squared_error: 4.1331e-04
# Epoch 97/100
# 215/215 [==============================] - 36s 170ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1572e-04 - val_mean_squared_error: 4.1282e-04
# Epoch 98/100
# 215/215 [==============================] - 38s 179ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1093e-04 - val_mean_squared_error: 4.0803e-04
# Epoch 99/100
# 215/215 [==============================] - 36s 169ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.1760e-04 - val_mean_squared_error: 4.1469e-04
# Epoch 100/100
# 215/215 [==============================] - 38s 178ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.0919e-04 - val_mean_squared_error: 4.0628e-04
# INFO:tensorflow:Assets written to: ./defensive_models/MNIST_II/assets

# %% [markdown]
# test_defense

# %%
detector_I = AEDetector("./defensive_models/MNIST_I", p=2)
detector_II = AEDetector("./defensive_models/MNIST_II", p=1)
reformer = SimpleReformer("./defensive_models/MNIST_I")

id_reformer = IdReformer()
classifier = Classifier("./models/example_classifier")

detector_dict = dict()
detector_dict["I"] = detector_I
detector_dict["II"] = detector_II

operator = Operator(MNIST(), classifier, detector_dict, reformer)

idx = load_obj("example_idx")
_, _, Y = prepare_data(MNIST(), idx)
f = "example_carlini_0.0"
testAttack = AttackData(f, Y, "Carlini L2 0.0")

evaluator = Evaluator(operator, testAttack)
evaluator.plot_various_confidences("defense_performance",
                                   drop_rate={"I": 0.001, "II": 0.001})
# Out:
# ==========================================================
# Drop Rate: {'I': 0.001, 'II': 0.001}
# Classification accuracy with all defense on: 0.9904
# ----------------------------------------------------------
# Confidence: 0.0
# {'I': 9801, 'II': 2187}
# ----------------------------------------------------------
# Confidence: 10.0
# {'I': 9534, 'II': 641}
# ----------------------------------------------------------
# Confidence: 20.0
# {'I': 8946, 'II': 149}
# ----------------------------------------------------------
# Confidence: 30.0
# {'I': 7940, 'II': 20}
# ----------------------------------------------------------
# Confidence: 40.0
# {'I': 6738, 'II': 1}
