# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#  ### 1번

# %%
import pandas as pd
import numpy as np

total_data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/[ACEE405] Datacon#2_Data.xlsx', sheet_name=None)

min60_y10=total_data['60m_10y']
min60_y20=total_data['60m_20y']
min60_y30=total_data['60m_30y']
min120_y10=total_data['120m_10y']
min120_y20=total_data['120m_20y']
min120_y30=total_data['120m_30y']

# %%
min60_y10.columns=min60_y10.iloc[0,:]
min60_y20.columns=min60_y20.iloc[0,:]
min60_y30.columns=min60_y30.iloc[0,:]
min120_y10.columns=min120_y10.iloc[0,:]
min120_y20.columns=min120_y20.iloc[0,:]
min120_y30.columns=min120_y30.iloc[0,:]

# %%
min60_y10_h1=min60_y10.iloc[1:,:5]
min60_y10_h2=min60_y10.iloc[1:,5:10]
min60_y10_h3=min60_y10.iloc[1:,10:15]
min60_y10_h4=min60_y10.iloc[1:,15:]

min60_y20_h1=min60_y20.iloc[1:,:5]
min60_y20_h2=min60_y20.iloc[1:,5:10]
min60_y20_h3=min60_y20.iloc[1:,10:15]
min60_y20_h4=min60_y20.iloc[1:,15:]

min60_y30_h1=min60_y30.iloc[1:,:5]
min60_y30_h2=min60_y30.iloc[1:,5:10]
min60_y30_h3=min60_y30.iloc[1:,10:15]
min60_y30_h4=min60_y30.iloc[1:,15:]

min120_y10_h1=min120_y10.iloc[1:,:5]
min120_y10_h2=min120_y10.iloc[1:,5:10]
min120_y10_h3=min120_y10.iloc[1:,10:15]
min120_y10_h4=min120_y10.iloc[1:,15:]

min120_y20_h1=min120_y20.iloc[1:,:5]
min120_y20_h2=min120_y20.iloc[1:,5:10]
min120_y20_h3=min120_y20.iloc[1:,10:15]
min120_y20_h4=min120_y20.iloc[1:,15:]

min120_y30_h1=min120_y30.iloc[1:,:5]
min120_y30_h2=min120_y30.iloc[1:,5:10]
min120_y30_h3=min120_y30.iloc[1:,10:15]
min120_y30_h4=min120_y30.iloc[1:,15:]

# %%
min60_y10_h1['10mins accumulated rainfall']=0
min60_y20_h1['10mins accumulated rainfall']=0
min60_y30_h1['10mins accumulated rainfall']=0
min120_y10_h1['10mins accumulated rainfall']=0
min120_y20_h1['10mins accumulated rainfall']=0
min120_y30_h1['10mins accumulated rainfall']=0

min60_y10_h2['10mins accumulated rainfall']=0
min60_y20_h2['10mins accumulated rainfall']=0
min60_y30_h2['10mins accumulated rainfall']=0
min120_y10_h2['10mins accumulated rainfall']=0
min120_y20_h2['10mins accumulated rainfall']=0
min120_y30_h2['10mins accumulated rainfall']=0

min60_y10_h3['10mins accumulated rainfall']=0
min60_y20_h3['10mins accumulated rainfall']=0
min60_y30_h3['10mins accumulated rainfall']=0
min120_y10_h3['10mins accumulated rainfall']=0
min120_y20_h3['10mins accumulated rainfall']=0
min120_y30_h3['10mins accumulated rainfall']=0

min60_y10_h4['10mins accumulated rainfall']=0
min60_y20_h4['10mins accumulated rainfall']=0
min60_y30_h4['10mins accumulated rainfall']=0
min120_y10_h4['10mins accumulated rainfall']=0
min120_y20_h4['10mins accumulated rainfall']=0
min120_y30_h4['10mins accumulated rainfall']=0

# %%
for i in range(len(min60_y10_h1.index)-10):
  x=i//10
  min60_y10_h1.iloc[i+1,5]=sum(min60_y10_h1.iloc[x*10+1:(x+1)*10+1,1])
  min60_y10_h2.iloc[i+1,5]=sum(min60_y10_h2.iloc[x*10+1:(x+1)*10+1,1])
  min60_y10_h3.iloc[i+1,5]=sum(min60_y10_h3.iloc[x*10+1:(x+1)*10+1,1])
  min60_y10_h4.iloc[i+1,5]=sum(min60_y10_h4.iloc[x*10+1:(x+1)*10+1,1])

  min60_y20_h1.iloc[i+1,5]=sum(min60_y20_h1.iloc[x*10+1:(x+1)*10+1,1])
  min60_y20_h2.iloc[i+1,5]=sum(min60_y20_h2.iloc[x*10+1:(x+1)*10+1,1])
  min60_y20_h3.iloc[i+1,5]=sum(min60_y20_h3.iloc[x*10+1:(x+1)*10+1,1])
  min60_y20_h4.iloc[i+1,5]=sum(min60_y20_h4.iloc[x*10+1:(x+1)*10+1,1])

  min60_y30_h1.iloc[i+1,5]=sum(min60_y30_h1.iloc[x*10+1:(x+1)*10+1,1])
  min60_y30_h2.iloc[i+1,5]=sum(min60_y30_h2.iloc[x*10+1:(x+1)*10+1,1])
  min60_y30_h3.iloc[i+1,5]=sum(min60_y30_h3.iloc[x*10+1:(x+1)*10+1,1])
  min60_y30_h4.iloc[i+1,5]=sum(min60_y30_h4.iloc[x*10+1:(x+1)*10+1,1])

  min120_y10_h1.iloc[i+1,5]=sum(min120_y10_h1.iloc[x*10+1:(x+1)*10+1,1])
  min120_y10_h2.iloc[i+1,5]=sum(min120_y10_h2.iloc[x*10+1:(x+1)*10+1,1])
  min120_y10_h3.iloc[i+1,5]=sum(min120_y10_h3.iloc[x*10+1:(x+1)*10+1,1])
  min120_y10_h4.iloc[i+1,5]=sum(min120_y10_h4.iloc[x*10+1:(x+1)*10+1,1])

  min120_y20_h1.iloc[i+1,5]=sum(min120_y20_h1.iloc[x*10+1:(x+1)*10+1,1])
  min120_y20_h2.iloc[i+1,5]=sum(min120_y20_h2.iloc[x*10+1:(x+1)*10+1,1])
  min120_y20_h3.iloc[i+1,5]=sum(min120_y20_h3.iloc[x*10+1:(x+1)*10+1,1])
  min120_y20_h4.iloc[i+1,5]=sum(min120_y20_h4.iloc[x*10+1:(x+1)*10+1,1])

  min120_y30_h1.iloc[i+1,5]=sum(min120_y30_h1.iloc[x*10+1:(x+1)*10+1,1])
  min120_y30_h2.iloc[i+1,5]=sum(min120_y30_h2.iloc[x*10+1:(x+1)*10+1,1])
  min120_y30_h3.iloc[i+1,5]=sum(min120_y30_h3.iloc[x*10+1:(x+1)*10+1,1])
  min120_y30_h4.iloc[i+1,5]=sum(min120_y30_h4.iloc[x*10+1:(x+1)*10+1,1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4402f7465fb4> in <module>()
#       3   min60_y10_h1.iloc[i+1,5]=sum(min60_y10_h1.iloc[x*10+1:(x+1)*10+1,1])
#       4   min60_y10_h2.iloc[i+1,5]=sum(min60_y10_h2.iloc[x*10+1:(x+1)*10+1,1])
# ----> 5   min60_y10_h3.iloc[i+1,5]=sum(min60_y10_h3.iloc[x*10+1:(x+1)*10+1,1])
#       6   min60_y10_h4.iloc[i+1,5]=sum(min60_y10_h4.iloc[x*10+1:(x+1)*10+1,1])
#       7
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
# ...

# %%
min60_y10_h1

# %%
import matplotlib.pyplot as plt

plt.bar(min120_y10_h1.iloc[:,0],min120_y10_h1.iloc[:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 1')
plt.show()

# %%
plt.bar(min120_y10_h2.iloc[1:,0],min120_y10_h2.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 2')
plt.show()

# %%
plt.bar(min120_y10_h3.iloc[1:,0],min120_y10_h3.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 3')
plt.show()

# %%
plt.bar(min120_y10_h4.iloc[1:,0],min120_y10_h4.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 4')
plt.show()

# %%
plt.bar(min60_y30_h1.iloc[1:,0],min60_y30_h1.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 1')
plt.show()

# %%
plt.bar(min60_y20_h2.iloc[1:,0],min60_y20_h2.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 2')
plt.show()

# %%
plt.bar(min60_y20_h3.iloc[1:,0],min60_y20_h3.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 3')
plt.show()

# %%
plt.bar(min60_y20_h4.iloc[1:,0],min60_y20_h4.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 4')
plt.show()

# %%
plt.bar(min60_y30_h1.iloc[1:,0],min60_y30_h1.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 1')
plt.show()

# %%
plt.bar(min60_y30_h2.iloc[1:,0],min60_y30_h2.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 2')
plt.show()

# %%
plt.bar(min60_y30_h3.iloc[1:,0],min60_y30_h3.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 3')
plt.show()

# %%
plt.bar(min60_y30_h4.iloc[1:,0],min60_y30_h4.iloc[1:,5])
plt.xlabel('index')
plt.ylabel('10min accumulated rainfall')
plt.title('Hyetograph of accumulated rainfall (10min) - Huff 4')
plt.show()

# %% [markdown]
# 여기까지가 rainfall - min60_y10~min60_y30까지 함

# %%
plt.plot(min60_y30_h1.iloc[1:,0],min60_y30_h1.iloc[1:,2])
plt.xlabel('index')
plt.ylabel('inflow data')
plt.title('line graph of inflow data - Huff 1')
plt.show()

# %%
plt.plot(min120_y10_h2.iloc[1:,0],min120_y10_h2.iloc[1:,2])
plt.xlabel('index')
plt.ylabel('inflow data')
plt.title('line graph of inflow data - Huff 2')
plt.show()

# %%
plt.plot(min120_y10_h3.iloc[1:,0],min120_y10_h3.iloc[1:,2])
plt.xlabel('index')
plt.ylabel('inflow data')
plt.title('line graph of inflow data - Huff 3')
plt.show()

# %%
plt.plot(min120_y10_h4.iloc[1:,0],min120_y10_h4.iloc[1:,2])
plt.xlabel('index')
plt.ylabel('inflow data')
plt.title('line graph of inflow data - Huff 4')
plt.show()

# %% [markdown]
# 여기까지가 inflow data - min60_y10밖에 안함.

# %%
plt.plot(min60_y30_h1.iloc[1:,0],min60_y30_h1.iloc[1:,3])
plt.xlabel('index')
plt.ylabel('depth data')
plt.title('line graph of depth data - Huff 1')
plt.show()

# %%
plt.plot(min120_y10_h2.iloc[1:,0],min120_y10_h2.iloc[1:,3])
plt.xlabel('index')
plt.ylabel('depth data')
plt.title('line graph of depth data - Huff 2')
plt.show()

# %%
plt.plot(min120_y10_h3.iloc[1:,0],min120_y10_h3.iloc[1:,3])
plt.xlabel('index')
plt.ylabel('depth data')
plt.title('line graph of depth data - Huff 3')
plt.show()

# %%
plt.plot(min120_y10_h4.iloc[1:,0],min120_y10_h4.iloc[1:,3])
plt.xlabel('index')
plt.ylabel('depth data')
plt.title('line graph of depth data - Huff 4')
plt.show()

# %% [markdown]
# 여기까지가 depth data - min60_y10만 함.

# %%
plt.plot(min60_y30_h1.iloc[1:,0],min60_y30_h1.iloc[1:,4])
plt.xlabel('index')
plt.ylabel('PumpQ data')
plt.title('step chart of PumpQ data - Huff 1')
plt.show()

# %%
plt.plot(min120_y10_h2.iloc[1:,0],min120_y10_h2.iloc[1:,4])
plt.xlabel('index')
plt.ylabel('PumpQ data')
plt.title('step chart of PumpQ data - Huff 2')
plt.show()

# %%
plt.plot(min120_y10_h3.iloc[1:,0],min120_y10_h3.iloc[1:,4])
plt.xlabel('index')
plt.ylabel('PumpQ data')
plt.title('step chart of PumpQ data - Huff 3')
plt.show()

# %%
plt.plot(min120_y10_h4.iloc[1:,0],min120_y10_h4.iloc[1:,4])
plt.xlabel('index')
plt.ylabel('PumpQ data')
plt.title('step chart of PumpQ data - Huff 4')
plt.show()

# %% [markdown]
# 여기까지가 PumpQ data. min60_y10만 함.

# %% [markdown]
# Analyze the characteristics and the tendency of the data as the rainfall duration,
# frequency and Huff distribution changes over cases.

# %% [markdown]
# 60m : 몇분동안 지속되는 강우인지
#
# 20y : 몇년에 한번정도 꼴로 발생하는 강우인지

# %% [markdown]
# ### 2번

# %%
import pandas as pd
import numpy as np

total_data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/[ACEE405] Datacon#2_Data.xlsx', sheet_name=None)

min60_y10=total_data['60m_10y']
min60_y20=total_data['60m_20y']
min60_y30=total_data['60m_30y']
min120_y10=total_data['120m_10y']
min120_y20=total_data['120m_20y']
min120_y30=total_data['120m_30y']

# %%
min60_y10.columns=min60_y10.iloc[0,:]
min60_y20.columns=min60_y20.iloc[0,:]
min60_y30.columns=min60_y30.iloc[0,:]
min120_y10.columns=min120_y10.iloc[0,:]
min120_y20.columns=min120_y20.iloc[0,:]
min120_y30.columns=min120_y30.iloc[0,:]

# %%
min60_y10_h1=min60_y10.iloc[1:,:5]
min60_y10_h2=min60_y10.iloc[1:,5:10]
min60_y10_h3=min60_y10.iloc[1:,10:15]
min60_y10_h4=min60_y10.iloc[1:,15:]

min60_y20_h1=min60_y20.iloc[1:,:5]
min60_y20_h2=min60_y20.iloc[1:,5:10]
min60_y20_h3=min60_y20.iloc[1:,10:15]
min60_y20_h4=min60_y20.iloc[1:,15:]

min60_y30_h1=min60_y30.iloc[1:,:5]
min60_y30_h2=min60_y30.iloc[1:,5:10]
min60_y30_h3=min60_y30.iloc[1:,10:15]
min60_y30_h4=min60_y30.iloc[1:,15:]

min120_y10_h1=min120_y10.iloc[1:,:5]
min120_y10_h2=min120_y10.iloc[1:,5:10]
min120_y10_h3=min120_y10.iloc[1:,10:15]
min120_y10_h4=min120_y10.iloc[1:,15:]

min120_y20_h1=min120_y20.iloc[1:,:5]
min120_y20_h2=min120_y20.iloc[1:,5:10]
min120_y20_h3=min120_y20.iloc[1:,10:15]
min120_y20_h4=min120_y20.iloc[1:,15:]

min120_y30_h1=min120_y30.iloc[1:,:5]
min120_y30_h2=min120_y30.iloc[1:,5:10]
min120_y30_h3=min120_y30.iloc[1:,10:15]
min120_y30_h4=min120_y30.iloc[1:,15:]

# %%
min60_y10_h1['Total']=2.11
min60_y10_h2['Total']=411.1
min60_y10_h3['Total']=735.62
min60_y10_h4['Total']=1303.63

min60_y20_h1['Total']=831.39
min60_y20_h2['Total']=1714.86
min60_y20_h3['Total']=2166.25
min60_y20_h4['Total']=2918.89

#min60_y30_h1['Total']=2.11
min60_y30_h2['Total']=2664.7
min60_y30_h3['Total']=3254.23
min60_y30_h4['Total']=4175.67

min120_y10_h1['Total']=0
min120_y10_h2['Total']=133.53
min120_y10_h3['Total']=443.02
min120_y10_h4['Total']=1581.73

min120_y20_h1['Total']=792.72
#min120_y20_h2['Total']=411.1
min120_y20_h3['Total']=1931.81
min120_y20_h4['Total']=3677.78

min120_y30_h1['Total']=1629.97
min120_y30_h2['Total']=2543.7
min120_y30_h3['Total']=3189
min120_y30_h4['Total']=5344.85

# %%
min60_y10_h1
# Out:
# 0     Time  Rainfall    Inflow     Depth PumpQ  Total
# 1      1.0       0.0       0.0       5.2   0.0   2.11
# 2      2.0  1.872656       0.0       5.2   0.0   2.11
# 3      3.0  2.301405  0.005677  5.200341   0.0   2.11
# 4      4.0  2.628492   0.02129  5.201618   0.0   2.11
# 5      5.0  2.865999  0.059591  5.205194   0.0   2.11
# ..     ...       ...       ...       ...   ...    ...
# 356  356.0       0.0  0.031884    6.0742   0.0   2.11
# 357  357.0       0.0  0.031555  6.074873   0.0   2.11
# 358  358.0       0.0  0.031205  6.075538   0.0   2.11
# 359  359.0       0.0  0.030867  6.076196   0.0   2.11
# 360  360.0       0.0  0.030493  6.076847   0.0   2.11
#
# [360 rows x 6 columns]

# %% [markdown]
# 데이터 전처리

# %%
#from tabulate import tabulate

huff1_list = [min60_y10_h1,min60_y20_h1, min120_y10_h1, min120_y20_h1, min120_y30_h1]
huff1_all = pd.concat(huff1_list, axis=0)
huff1_all = huff1_all.reset_index(drop=True)
huff1_all = huff1_all.drop('Time',axis=1)
#huff1_all['Total']=2.11
#huff1_all.astype('float')

huff2_list = [min60_y10_h2,min60_y20_h2, min60_y30_h2, min120_y10_h2, min120_y30_h2]
huff2_all = pd.concat(huff2_list, axis=0)
huff2_all = huff2_all.reset_index(drop=True)
huff2_all = huff2_all.drop('Time',axis=1)
#huff2_all['Total']=411.1
#huff2_all.astype('float')

huff3_list = [min60_y10_h3,min60_y20_h3, min60_y30_h3, min120_y10_h3, min120_y20_h3, min120_y30_h3]
huff3_all = pd.concat(huff3_list, axis=0)
huff3_all = huff3_all.reset_index(drop=True)
huff3_all = huff3_all.drop('Time',axis=1)
#huff3_all['Total']=735.62
#huff3_all.astype('float')

huff4_list = [min60_y10_h4,min60_y20_h4, min60_y30_h4, min120_y10_h4, min120_y20_h4, min120_y30_h4]
huff4_all = pd.concat(huff4_list, axis=0)
huff4_all = huff4_all.reset_index(drop=True)
huff4_all = huff4_all.drop('Time',axis=1)
#huff4_all['Total']=1303.63
#huff4_all.astype('float')

huff1_all = huff1_all.reset_index(drop=True)
huff2_all = huff2_all.reset_index(drop=True)
huff3_all = huff3_all.reset_index(drop=True)
huff4_all = huff4_all.reset_index(drop=True)

# %%
idx_nm_1 = huff1_all[huff1_all["Rainfall"]==0].index
idx_nm_2 = huff1_all[huff1_all["Inflow"]==0].index
idx_nm_3 = huff1_all[huff1_all["Depth"]==0].index
idx_nm_4 = huff1_all[huff1_all["PumpQ"]==0].index

idx_nm = []
idx_nm.extend(idx_nm_1)
idx_nm.extend(idx_nm_2)
idx_nm.extend(idx_nm_3)
idx_nm.extend(idx_nm_4)

huff1_all = huff1_all.drop(idx_nm)#,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_2,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_3,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_4,inplace=True)

# %%
idx_nm_1 = huff2_all[huff2_all["Rainfall"]==0].index
idx_nm_2 = huff2_all[huff2_all["Inflow"]==0].index
idx_nm_3 = huff2_all[huff2_all["Depth"]==0].index
idx_nm_4 = huff2_all[huff2_all["PumpQ"]==0].index

idx_nm = []
idx_nm.extend(idx_nm_1)
idx_nm.extend(idx_nm_2)
idx_nm.extend(idx_nm_3)
idx_nm.extend(idx_nm_4)

huff2_all = huff2_all.drop(idx_nm)#,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_2,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_3,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_4,inplace=True)

# %%
idx_nm_1 = huff3_all[huff3_all["Rainfall"]==0].index
idx_nm_2 = huff3_all[huff3_all["Inflow"]==0].index
idx_nm_3 = huff3_all[huff3_all["Depth"]==0].index
idx_nm_4 = huff3_all[huff3_all["PumpQ"]==0].index

idx_nm = []
idx_nm.extend(idx_nm_1)
idx_nm.extend(idx_nm_2)
idx_nm.extend(idx_nm_3)
idx_nm.extend(idx_nm_4)

huff3_all = huff3_all.drop(idx_nm)#,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_2,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_3,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_4,inplace=True)

# %%
idx_nm_1 = huff4_all[huff4_all["Rainfall"]==0].index
idx_nm_2 = huff4_all[huff4_all["Inflow"]==0].index
idx_nm_3 = huff4_all[huff4_all["Depth"]==0].index
idx_nm_4 = huff4_all[huff4_all["PumpQ"]==0].index

idx_nm = []
idx_nm.extend(idx_nm_1)
idx_nm.extend(idx_nm_2)
idx_nm.extend(idx_nm_3)
idx_nm.extend(idx_nm_4)

huff4_all = huff4_all.drop(idx_nm)#,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_2,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_3,inplace=True)
#huff1_all = huff1_all.drop(idx_nm_4,inplace=True)

# %%
huff1_all
# Out:
# 0     Rainfall    Inflow     Depth  PumpQ    Total
# 15    2.244732  8.299595  6.468910  100.0     2.11
# 16    2.074265  8.864599  6.582510  200.0     2.11
# 17    1.905430  9.398696  6.707080  200.0     2.11
# 18    1.741089  9.489618  6.799288  300.0     2.11
# 19    1.583652  9.586161  6.893478  300.0     2.11
# ...        ...       ...       ...    ...      ...
# 1555  0.332886  3.240987  6.076948  300.0  1629.97
# 1556  0.354988  3.189811  6.038351  300.0  1629.97
# 1557  0.383644  3.145936  5.998819  300.0  1629.97
# 1558  0.419441  3.111338  5.958549  300.0  1629.97
# 1559  0.463120  3.088201  5.917786  300.0  1629.97
#
# [376 rows x 5 columns]

# %%
huff_list = [huff1_all, huff2_all, huff3_all, huff4_all]
huff = pd.concat(huff_list)

huff
# Out:
# 0     Rainfall    Inflow     Depth  PumpQ    Total
# 15    2.244732  8.299595   6.46891  100.0     2.11
# 16    2.074265  8.864599   6.58251  200.0     2.11
# 17     1.90543  9.398696   6.70708  200.0     2.11
# 18    1.741089  9.489618  6.799288  300.0     2.11
# 19    1.583652  9.586161  6.893478  300.0     2.11
# ...        ...       ...       ...    ...      ...
# 1915  1.851875  12.96366  7.675774  640.0  5344.85
# 1916  1.600632  12.70305  7.709221  640.0  5344.85
# 1917   1.31514   12.4018   7.73772  640.0  5344.85
# 1918  0.993118  12.06586  7.760702  640.0  5344.85
# 1919  0.632263  11.67295   7.77723  640.0  5344.85
#
# [1235 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
huff.iloc[:,:4]=scaler.fit_transform(huff.iloc[:,:4])
huff=huff.astype(float)

# %%
huff
# Out:
# 0     Rainfall    Inflow     Depth     PumpQ    Total
# 15    0.528663  0.490957  0.528747  0.000000     2.11
# 16    0.488468  0.534513  0.569666  0.185185     2.11
# 17    0.448658  0.575685  0.614535  0.185185     2.11
# 18    0.409907  0.582694  0.647748  0.370370     2.11
# 19    0.372784  0.590137  0.681675  0.370370     2.11
# ...        ...       ...       ...       ...      ...
# 1915  0.436030  0.850503  0.963456  1.000000  5344.85
# 1916  0.376788  0.830413  0.975503  1.000000  5344.85
# 1917  0.309471  0.807190  0.985769  1.000000  5344.85
# 1918  0.233540  0.781293  0.994047  1.000000  5344.85
# 1919  0.148452  0.751004  1.000000  1.000000  5344.85
#
# [1235 rows x 5 columns]

# %%
huff1_all=huff1_all.astype(float)

# %%
import pandas as pd
import tensorflow as tf
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# 데이터 로드
X = huff.iloc[:,:4]
Y = huff.iloc[:,4]
#X

# 데이터 전처리
#X_scaled= MinMaxScaler().fit_transform(X)

# 훈련셋, 시험셋 나누기(랜덤서치를 이용한 교차검증 수행 예정)
train_input, test_input, train_target, test_target = train_test_split(X, Y, test_size=0.2)
#train_input, val_input, train_target, val_target = train_test_split(train_input, train_target, test_size=0.25)

model=LinearRegression()
model.fit(train_input, train_target)

# 모델 평가
print(model.score(test_input, test_target))

# 정확도, 손실 그래프 그리기
#import matplotlib.pyplot as plt

#history_dict = history.history

#acc = history_dict['accuracy']
#val_acc = history_dict['val_accuracy']
#loss = history_dict['loss']
#val_loss = history_dict['val_loss']

#epochs = range(1, len(acc)+1)

#loss_ax = plt.subplot()
#acc_ax = loss_ax.twinx()

#loss_ax.plot(epochs, loss, 'y', label='Training loss')
#loss_ax.plot(epochs, val_loss, 'r', label='validation loss')
#loss_ax.legend(loc='upper left')

#acc_ax.plot(epochs, acc, 'b', label='Training acc')
#acc_ax.plot(epochs, val_acc, 'g', label='validation acc')
#acc_ax.legend(loc='upper right')

#plt.title('Accuracy and loss changes with epochs')
#loss_ax.set_xlabel('Epochs')
#loss_ax.set_ylabel('Loss')
#acc_ax.set_ylabel('Accuracy')
#plt.show()
# Out:
# 0.22104586901887524

# %%
idx_nm_1 = min60_y10_h1[min60_y10_h1["Rainfall"]==0].index
idx_nm_2 = min60_y10_h1[min60_y10_h1["Inflow"]==0].index
idx_nm_3 = min60_y10_h1[min60_y10_h1["Depth"]==0].index
idx_nm_4 = min60_y10_h1[min60_y10_h1["PumpQ"]==0].index

idx_nm = []
idx_nm.extend(idx_nm_1)
idx_nm.extend(idx_nm_2)
idx_nm.extend(idx_nm_3)
idx_nm.extend(idx_nm_4)

min60_y10_h1 = min60_y10_h1.drop(idx_nm)#,inplace=True)

# %%
min60_y10_h1.drop(columns='Total',inplace=True)

# %%
min60_y10_h1.iloc[:,:4]=scaler.fit_transform(min60_y10_h1.iloc[:,:4])
min60_y10_h1=min60_y10_h1.astype(float)

# %%
print((model.predict(min60_y10_h1)).mean())
# Out:
# 1589.0592242385403

# %%
print(min60_y10_h1)
# Out:
# 0   Rainfall    Inflow     Depth     PumpQ  Total
# 16  1.000000  0.751933  0.698881  0.000000    0.0
# 17  0.910209  0.849333  0.760555  0.185185    0.0
# 18  0.821277  0.941404  0.828183  0.185185    0.0
# 19  0.734712  0.957078  0.878243  0.370370    0.0
# 20  0.651785  0.973721  0.929378  0.370370    0.0
# 21  0.573533  0.884706  0.943165  0.685185    0.0
# 22  0.500788  1.000000  0.964408  0.685185    0.0
# 23  0.434169  0.982169  0.984499  0.685185    0.0
# 24  0.374120  0.960739  1.000000  0.685185    0.0
# 25  0.320910  0.939568  0.988599  1.000000    0.0
# 26  0.274641  0.919277  0.973377  1.000000    0.0
# 27  0.235270  0.887477  0.955752  1.000000    0.0
# 28  0.202642  0.882114  0.937779  1.000000    0.0
# 29  0.176451  0.851212  0.917807  1.000000    0.0
# 30  0.156319  0.880549  0.899733  1.000000    0.0
# 31  0.141765  0.758440  0.873761  1.000000    0.0
# 32  0.132233  0.718588  0.845212  1.000000    0.0
# 33  0.127103  0.674954  0.813840  1.000000    0.0
# ...
